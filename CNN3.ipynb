# %% [markdown]
# # IMPORTS

# %%
#Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import product
from math import ceil

# Scikit Learn
from sklearn.model_selection import KFold

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# # DATA PREP

# %% [markdown]
# ### Load and Split

# %%
# Load the data
data_train = np.load('fashion_train.npy', mmap_mode = 'r')
data_test = np.load('fashion_test.npy', mmap_mode = 'r')

# Split and normalize the data
# We divide the X arrays by 255 to ensure they lay in the range [0, 1].
# We can do this scaling before splitting into training and validation in KFolds since
# it is by a constant already known value (255)
X_train = data_train[:, :-1] / 255
y_train = data_train[:, -1]
X_test = data_test[:, :-1] / 255
y_test = data_test[:, -1]

# %% [markdown]
# # CNN

# %%
# Create custom CNN model
class CNN(nn.Module):
    '''
    Custom Convolutional Neural Network model for image classification.
    Based on LeNet architecture.

    Attributes:
        n_classes (int): Number of output classes.
        activation_fn (torch.nn.modules.activation): Activation function to use in the network layers.
        learning_rate (float): Learning rate for the optimizer.
        dropout_rate (float): Dropout rate for dropout layers.
        optimizer (torch.optim.Optimizer): Optimizer to use for training.
        criterion (torch.nn.modules.loss): Loss function.
        tr_loader (torch.utils.data.DataLoader): DataLoader for training data.
        val_loader (torch.utils.data.DataLoader): DataLoader for validation data.
        best_epoch (int): Epoch number with the best validation performance.
        train_losses (dict): Dictionary storing training losses per epoch.
        train_accuracies (dict): Dictionary storing training accuracies per epoch.
        val_losses (dict): Dictionary storing validation losses per epoch.
        val_accuracies (dict): Dictionary storing validation accuracies per epoch.
        scheduler (torch.optim.lr_scheduler): Learning rate scheduler.
        batch_size (int): Batch size used for data loading.
        n_epochs (int): Number of epochs for training.
        patience (int): Number of epochs to wait for improvement before stopping.
        verbose (bool): Flag to enable printing of training and validation statistics.

    Params:
        n_classes (int): Number of output classes.
        activation_fn (torch.nn.modules.activation): Activation function to use in the network layers.
        learning_rate (float): Learning rate for the optimizer.
        dropout_rate (float): Dropout rate for dropout layers.
        optimizer (torch.optim.Optimizer): Optimizer to use for training.
        criterion (torch.nn.modules.loss): Loss function.
        tr_data (torch.utils.data.Dataset): Training dataset.
        val_data (torch.utils.data.Dataset): Validation dataset.
        batch_size (int): Batch size used for data loading.
        n_epochs (int, optional): Number of epochs for training. Defaults to 100.
        patience (int, optional): Number of epochs to wait for improvement before stopping. Defaults to 10.
        verbose (bool, optional): Flag to enable printing of training and validation statistics. Defaults to False.
    '''
    def __init__(self, 
                 n_classes: int, 
                 activation_fn: torch.nn.modules.activation, 
                 learning_rate: float, 
                 dropout_rate: float, 
                 optimizer: torch.optim.Optimizer, 
                 criterion: torch.nn.modules.loss, 
                 tr_data,
                 val_data, 
                 batch_size: int, 
                 n_epochs: int = 100, 
                 patience: int = 10, 
                 verbose: bool = False
                 ):
        
        super(CNN, self).__init__()

        # Define functions
        self.activation_fn = activation_fn
        self.criterion = criterion

        # Define variables
        self.n_epochs = n_epochs
        self.patience = patience
        self.verbose = verbose
        self.batch_size = batch_size

        # Keep statistics
        self.best_epoch = 0 # Use as key to find values in below dicts
        self.train_losses = {0: float('inf')}
        self.train_accuracies = {0: .0}
        self.val_losses = {0: float('inf')}
        self.val_accuracies = {0: .0}

        # Define data sets
        self.tr_loader = DataLoader(tr_data, batch_size = batch_size, shuffle = True)
        self.val_loader = DataLoader(val_data, batch_size = batch_size, shuffle = False)

        ### DEFINE ARCHITECTURE

        # First convolutional block
        self.conv1_block = nn.Sequential(
            nn.Conv2d(1, 6, kernel_size = 5, stride = 1, padding = 2),
            nn.BatchNorm2d(6),
            self.activation_fn(),
            nn.AvgPool2d(kernel_size = 2, stride = 2)
        )

        # Second convolutional block
        self.conv2_block = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Conv2d(6, 16, kernel_size = 5),
            nn.BatchNorm2d(16),
            self.activation_fn(),
            nn.AvgPool2d(kernel_size = 2, stride = 2)
        )

        # Fully connected layers
        self.fc_block = nn.Sequential(

            # First fully connected layer
            nn.Dropout(dropout_rate),
            nn.Linear(16 * 5 * 5, 120),
            nn.BatchNorm1d(120),
            self.activation_fn(),

            # Second fully connected layer
            nn.Dropout(dropout_rate),
            nn.Linear(120, 84),
            nn.BatchNorm1d(84),
            self.activation_fn(),

            # Output layer
            nn.Dropout(dropout_rate),
            nn.Linear(84, n_classes)
        )

        # Define optimizer
        self.optimizer = optimizer(self.parameters(), lr = learning_rate)

        # Define scheduler for reducing learning rates
        self.scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer = self.optimizer,
            patience = ceil(self.patience / 2), # Reduce learning rate once half of patience has passed
            verbose = self.verbose
        )
    
    def forward(self, x):
        '''
        Forward pass of the model.

        Params:
            x (torch.Tensor): Input data.

        Returns:
            output (torch.Tensor): Output of the model.
        '''
        output = self.conv1_block(x) # First convolutional block
        output = self.conv2_block(output) # Second convolutional block
        output = output.reshape(output.size(0), -1) # Flatten before passing to fully connected layers
        output = self.fc_block(output) # Pass to fully connected layers
        return output

    def train_loop(self):
        '''
        Training loop for a single epoch. Processes the training data in batches,
        performs forward and backward passes, and updates model parameters.
        '''
        # Enable batch normalization and dropout
        self.train()

        # Initiate training statistics
        train_loss = .0
        train_correct = 0

        # Iterate over each batch in training loader
        for imgs, labels in self.tr_loader:

            # Forward step
            outputs = self.forward(imgs)
            loss = self.criterion(outputs, labels)

            # Backwards step
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            # Update loss and correct
            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            train_correct += (predicted == labels).sum().item()

        # Compute average training loss and training accuracy
        avg_train_loss = train_loss / len(self.tr_loader) # Divide by number of batches
        train_accuracy = train_correct / len(self.tr_loader.dataset) * 100 # Divide by number of observations

        # Add average training loss and accuracy for the epoch to model statistics
        self.train_losses[self.epoch] = avg_train_loss
        self.train_accuracies[self.epoch] = train_accuracy

    def val_loop(self):
        '''
        Validation loop for a single epoch. Processes the validation data in batches
        and evaluates the model's performance.
        '''
        # Disable batch batch normalization and dropout
        self.eval()

        # Initiate validation statistics
        val_loss = .0
        val_correct = 0

        with torch.no_grad(): # Do not use gradient for validation
            for imgs, labels in self.val_loader:

                outputs = self.forward(imgs)
                loss = self.criterion(outputs, labels)

                # Update loss and correct
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_correct += (predicted == labels).sum().item()

        # Compute average validation loss and validation accuracy
        avg_val_loss = val_loss / len(self.val_loader) # Divide by number of batches
        val_accuracy = val_correct / len(self.val_loader.dataset) * 100 # Divide by number of observations

        # Add average validation loss and accuracy for the epoch to model statistics
        self.val_losses[self.epoch] = avg_val_loss
        self.val_accuracies[self.epoch] = val_accuracy

        # Step the scheduler based on the validation loss
        self.scheduler.step(val_loss)

    def fit(self):
        '''
        Run the fitting process for the model. Iteratively calls the training and validation
        loops for the specified number of epochs, with early stopping based on validation loss.
        '''
        # Run training and validation loop once for every epoch
        for epoch in range(self.n_epochs):

            # Keep track of current epoch
            self.epoch = epoch + 1 # Start from 1

            # Run training loop
            self.train_loop()

            # Run validation loop
            self.val_loop()

            # Print training and validation statistics
            if self.verbose: # and self.epoch % 5 == 0:
                print(f'Epoch {self.epoch}/{self.n_epochs}, ',
                    f'Train Loss: {self.train_losses[self.epoch]:.4f}, ',
                    f'Train Accuracy: {self.train_accuracies[self.epoch]:.2f}%, ',
                    f'Val Loss: {self.val_losses[self.epoch]:.4f}, ',
                    f'Val Accuracy: {self.val_accuracies[self.epoch]:.2f}%')

            # Run evaluation and break if patience have been met
            if self.evaluate_epoch():
                break

    def evaluate_epoch(self):
        '''
        Evaluate the model at the end of an epoch. Checks if the validation loss has improved
        and updates the best model if necessary.

        Returns:
            bool: True if early stopping condition is met, False otherwise.
        '''
        # Check if validation loss for current epoch is improvement
        if self.val_losses[self.epoch] < self.val_losses[self.best_epoch]:
            self.best_epoch = self.epoch # Update best epoch
            self.epochs_without_improvement = 0 # Create/reset early stopping counter variable
            self.save_model() # Safe this as new best model
        else:
            self.epochs_without_improvement += 1

        # Check if paitence for epochs without improvement have been reached
        if self.epochs_without_improvement >= self.patience:
            if self.verbose:
                print(f'Stopping at epoch {self.epoch} due to no improvement in validation loss over {self.patience} epochs.') 
            return True # Will break fit loop

    def predict(self, pred_data, batch_size: int = None, label_map: dict = None):
        '''
        Make predictions with the trained model.

        Params:
            pred_data (torch.utils.data.Dataset): Data for making predictions.
            batch_size (int, optional): Batch size for testing. Defaults to the initialized batch size.
            label_map (dict, optional): Map of class labels for predictions.

        Returns:
            numpy.ndarray: Predicted labels for the test data.
        '''
        # Disable batch batch normalization and dropout
        self.eval()

        # Use initialized batch size if nothing else specified
        if batch_size == None:
            batch_size = self.batch_size

        # Create data loader for prediction data
        pred_loader = DataLoader(pred_data, batch_size = batch_size, shuffle = False)

        # Keep predictions in list
        y_pred = []

        with torch.no_grad(): # Do not use gradient for prediction
            for X, _ in pred_loader:
                logits = self.forward(X)
                y_pred.append(logits.argmax(dim = 1))

        # Concatenate y_pred
        y_pred = torch.cat(y_pred, dim = 0)

        # Convert predictions to mapped labels if provided
        if label_map is not None:
            y_pred = [label_map[i] for i in y_pred]

        # Return as numpy array
        return y_pred.numpy()
    
    def test(self, test_data, batch_size: int = None):
        '''
        Test loop for evaluating the model on test data. Computes the loss and accuracy.

        Params:
            test_data (torch.utils.data.Dataset): Test dataset for evaluation.
            batch_size (int, optional): Batch size for testing. Defaults to the initialized batch size.

        Returns:
            dict: Dictionary containing 'Test Loss' and 'Test Accuracy'.
        '''
        # Disable batch batch normalization and dropout
        self.eval()

        # Use initialized batch size if nothing else specified
        if batch_size == None:
            batch_size = self.batch_size

        # Create data loader for test data
        test_loader = DataLoader(test_data, batch_size = batch_size, shuffle = False)

        # Initiate test statistics
        test_loss = .0
        test_correct = 0

        with torch.no_grad(): # Do not use gradient for testing
            for imgs, labels in test_loader:

                outputs = self.forward(imgs)
                loss = self.criterion(outputs, labels)

                # Update loss and correct
                test_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                test_correct += (predicted == labels).sum().item()

        # Compute average testing loss and accuracy
        avg_test_loss = test_loss / len(test_loader) # Divide by number of batches
        test_accuracy = test_correct / len(test_loader.dataset) * 100 # Divide by number of observations

        # Return dict of statistics
        return {'Test Loss': avg_test_loss, 'Test Accuracy': test_accuracy}

    def save_model(self, file_path = 'best_model.pth'):
        '''
        Save the current state of the model to a file.

        Params:
            file_path (str, optional): The file path to save the model. Defaults to 'best_model.pth'.
        '''
        torch.save(self.state_dict(), file_path)

    def load_model(self, file_path = 'best_model.pth'):
        '''
        Load a model's state from a file.

        Params:
            file_path (str, optional): The file path to load the model from. Defaults to 'best_model.pth'.
        '''
        self.load_state_dict(torch.load(file_path))
        self.eval() # Set the model to evaluation mode

# %% [markdown]
# # CROSS VALIDATION

# %%
# Define ranges of learning and dropout rates
learning_rates = [.0001, .001, .0025, .01, .025, .1, .2, .3] # [.0001, .001, .0025, .01, .025, .1, .25]
dropout_rates = [.0001, .001, .0025, .01, .1, .2, .3, .4, .5] # [.0001, .001, .0025, .01, .1, .2, .3] # 

# Define batch size
batch_size = 64

# Define number of folds for cross-validation
n_folds = 5
kf = KFold(n_splits = n_folds, shuffle = True, random_state = 17)

# Initialiaze empty data frame to store results
results_columns = ['LR', 'DPR', 'Train Loss', 'Train Accuracy', 'Val Loss', 'Val Accuracy']
results = pd.DataFrame(columns = results_columns)

# Print startup message
print('-'*60)
print('Running Cross Validation...')
print('-'*60)
print(f'Testing {len(learning_rates)} learning rates and {len(dropout_rates)} dropout rates for a total')
print(f'of {len(learning_rates) * len(dropout_rates)} combinations, each split into {n_folds} folds.')
print('-'*60)
hours, mins = divmod(1.9 * len(learning_rates) * len(dropout_rates) * n_folds, 60) # 1.9 multiplier is rough guess based on previous performance
print(f'Expected time: {int(hours)} hours, {int(mins)} minutes.')
print('-'*60)

# Take cartesian product to iterate over each combination of learning rate and dropout rate
for learning_rate, dropout_rate in product(learning_rates, dropout_rates):
    
    print('\n')
    print('-'*51)
    print(f'--- Learning Rate: {learning_rate:.4f}, Dropout Rate: {dropout_rate:.4f} ---')
    print('-'*51)

    # Lists to store statistics accuracies for each fold
    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []

    # Iterate over cross-validation folds
    for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):

        # Split data into training and validation sets for this fold
        X_train_fold = X_train[train_idx]
        y_train_fold = y_train[train_idx]
        X_val_fold = X_train[val_idx]
        y_val_fold = y_train[val_idx]

        # Convert to tensors
        X_train_fold_tensor = torch.tensor(X_train_fold, dtype = torch.float32).view(-1, 1, 28, 28) # Convert to convolutional input
        y_train_fold_tensor = torch.tensor(y_train_fold, dtype = torch.long)
        X_val_fold_tensor = torch.tensor(X_val_fold, dtype = torch.float32).view(-1, 1, 28, 28) # Convert to convolutional input
        y_val_fold_tensor = torch.tensor(y_val_fold, dtype = torch.long)

        # Create tensor datasets
        train_fold_dataset = TensorDataset(X_train_fold_tensor, y_train_fold_tensor)
        val_fold_dataset = TensorDataset(X_val_fold_tensor, y_val_fold_tensor)

        # Instantiate model
        model = CNN(
            n_classes = len(np.unique(y_train)),
            activation_fn = nn.Sigmoid,
            learning_rate = learning_rate,
            dropout_rate = dropout_rate,
            optimizer = torch.optim.Adam,
            criterion = nn.CrossEntropyLoss(reduction = 'mean'),
            tr_data = train_fold_dataset,
            val_data = val_fold_dataset,
            n_epochs = 200,
            batch_size = batch_size,
            verbose = True
        )

        print(f'\nRunning Fold {fold + 1}/{n_folds}..')

        # Fit model
        model.fit()

        # Get model statistics for this fold
        fold_best_epoch = model.best_epoch
        fold_best_epoch_tr_loss = model.train_losses[fold_best_epoch]
        fold_best_epoch_tr_acc = model.train_accuracies[fold_best_epoch]
        fold_best_epoch_val_loss = model.val_losses[fold_best_epoch]
        fold_best_epoch_val_acc = model.val_accuracies[fold_best_epoch]

        # Append fold statistic to lr/dpr combination statistics
        train_losses.append(fold_best_epoch_tr_loss)
        train_accuracies.append(fold_best_epoch_tr_acc)
        val_losses.append(fold_best_epoch_val_loss)
        val_accuracies.append(fold_best_epoch_val_acc)

        print(
            f'Results for Fold {fold + 1}/{n_folds}:\n',
            f'Best Epoch: {fold_best_epoch}, ',
            f'Train Loss: {fold_best_epoch_tr_loss:.4f}, ',
            f'Train Accuracy: {fold_best_epoch_tr_acc:.2f}%, '
            f'Val Loss: {fold_best_epoch_val_loss:.4f}, ', 
            f'Val Accuracy: {fold_best_epoch_val_acc:.2f}%'
        )

    # Update results data frame with data from combination of learning rate and dropout rate
    results = results.append({
        'LR': learning_rate,
        'DPR': dropout_rate,
        'Train Loss': sum(train_losses) / len(train_losses),
        'Train Accuracy': sum(train_accuracies) / len(train_accuracies),
        'Val Loss': sum(val_losses) / len(val_losses),
        'Val Accuracy': sum(val_accuracies) /len(val_accuracies)
    }, ignore_index = True)

    # Print final results for combination
    print(f'\nFinal Results for Learning Rate {learning_rate} and Dropout Rate {dropout_rate}:\n',
          f'Avg Train Loss: {sum(train_losses) / len(train_losses):.4f}, ',
          f'Avg Train Accuracy: {sum(train_accuracies) / len(train_accuracies):.2f}%, ',
          f'Avg Val Loss: {sum(val_losses) / len(val_losses):.4f}, ', 
          f'Avg Val Accuracy: {sum(val_accuracies) /len(val_accuracies):.2f}%')

# Save results to csv
results.to_csv('cross_validation3.csv')
print('\n', results)

# Extract best combination of learning rate and dropout rate from results data frame
# based on lowest validation loss
lowest_val_loss_idx = results.loc[results['Val Loss'].idxmin()]
best_combination = lowest_val_loss_idx['LR'], lowest_val_loss_idx['DPR'] # Save to tuple
# Out:
# ------------------------------------------------------------
# Running Cross Validation...
# ------------------------------------------------------------
# Testing 8 learning rates and 9 dropout rates for a total
# of 72 combinations, each split into 5 folds.
# ------------------------------------------------------------
# Expected time: 11 hours, 23 minutes.
# ------------------------------------------------------------
#
#
# ---------------------------------------------------
# --- Learning Rate: 0.0001, Dropout Rate: 0.0001 ---
# ---------------------------------------------------
#
# Running Fold 1/5..
# Epoch 1/200,  Train Loss: 1.2156,  Train Accuracy: 63.69%,  Val Loss: 1.0329,  Val Accuracy: 74.35%
# Epoch 2/200,  Train Loss: 0.9895,  Train Accuracy: 76.72%,  Val Loss: 0.9253,  Val Accuracy: 77.55%
# Epoch 3/200,  Train Loss: 0.9049,  Train Accuracy: 78.91%,  Val Loss: 0.8577,  Val Accuracy: 80.70%
# Epoch 4/200,  Train Loss: 0.8360,  Train Accuracy: 80.09%,  Val Loss: 0.7945,  Val Accuracy: 81.35%
# Epoch 5/200,  Train Loss: 0.7808,  Train Accuracy: 80.83%,  Val Loss: 0.7454,  Val Accuracy: 80.70%
# Epoch 6/200,  Train Loss: 0.7311,  Train Accuracy: 82.10%,  Val Loss: 0.7011,  Val Accuracy: 83.05%
# Epoch 7/200,  Train Loss: 0.6885,  Train Accuracy: 82.50%,  Val Loss: 0.6599,  Val Accuracy: 82.80%
# Epoch 8/200,  Train Loss: 0.6494,  Train Accuracy: 83.41%,  Val Loss: 0.6271,  Val Accuracy: 83.70%
# Epoch 9/200,  Train Loss: 0.6187,  Train Accuracy: 83.73%,  Val Loss: 0.6031,  Val Accuracy: 82.80%
# Epoch 10/200,  Train Loss: 0.5881,  Train Accuracy: 84.10%,  Val Loss: 0.5790,  Val Accuracy: 84.45%
# Epoch 11/200,  Train Loss: 0.5627,  Train Accuracy: 84.55%,  Val Loss: 0.5502,  Val Accuracy: 85.15%
# Epoch 12/200,  Train Loss: 0.5385,  Train Accuracy: 84.89%,  Val Loss: 0.5251,  Val Accuracy: 85.75%
# Epoch 13/200,  Train Loss: 0.5147,  Train Accuracy: 85.30%,  Val Loss: 0.5117,  Val Accuracy: 85.50%
# Epoch 14/200,  Train Loss: 0.4950,  Train Accuracy: 85.47%,  Val Loss: 0.4917,  Val Accuracy: 85.95%
# Epoch 15/200,  Train Loss: 0.4812,  Train Accuracy: 85.85%,  Val Loss: 0.4913,  Val Accuracy: 85.15%
# Epoch 16/200,  Train Loss: 0.4668,  Train Accuracy: 85.82%,  Val Loss: 0.4637,  Val Accuracy: 86.55%
# Epoch 17/200,  Train Loss: 0.4493,  Train Accuracy: 86.21%,  Val Loss: 0.4559,  Val Accuracy: 85.90%
# Epoch 18/200,  Train Loss: 0.4356,  Train Accuracy: 86.30%,  Val Loss: 0.4505,  Val Accuracy: 85.75%
# Epoch 19/200,  Train Loss: 0.4232,  Train Accuracy: 86.76%,  Val Loss: 0.4303,  Val Accuracy: 86.45%
# Epoch 20/200,  Train Loss: 0.4107,  Train Accuracy: 87.21%,  Val Loss: 0.4214,  Val Accuracy: 86.35%
# Epoch 21/200,  Train Loss: 0.4003,  Train Accuracy: 87.26%,  Val Loss: 0.4200,  Val Accuracy: 85.80%
# Epoch 22/200,  Train Loss: 0.3957,  Train Accuracy: 87.04%,  Val Loss: 0.4130,  Val Accuracy: 86.75%
# Epoch 23/200,  Train Loss: 0.3844,  Train Accuracy: 87.64%,  Val Loss: 0.4121,  Val Accuracy: 87.05%
# Epoch 24/200,  Train Loss: 0.3737,  Train Accuracy: 87.96%,  Val Loss: 0.4010,  Val Accuracy: 87.10%
# Epoch 25/200,  Train Loss: 0.3649,  Train Accuracy: 88.09%,  Val Loss: 0.4111,  Val Accuracy: 85.70%
# Epoch 26/200,  Train Loss: 0.3622,  Train Accuracy: 88.11%,  Val Loss: 0.4170,  Val Accuracy: 85.10%
# Epoch 27/200,  Train Loss: 0.3489,  Train Accuracy: 88.46%,  Val Loss: 0.3941,  Val Accuracy: 87.00%
# Epoch 28/200,  Train Loss: 0.3441,  Train Accuracy: 88.45%,  Val Loss: 0.3874,  Val Accuracy: 86.60%
# Epoch 29/200,  Train Loss: 0.3381,  Train Accuracy: 88.66%,  Val Loss: 0.3873,  Val Accuracy: 86.80%
# Epoch 30/200,  Train Loss: 0.3331,  Train Accuracy: 89.04%,  Val Loss: 0.3854,  Val Accuracy: 86.80%
# Epoch 31/200,  Train Loss: 0.3297,  Train Accuracy: 88.84%,  Val Loss: 0.3827,  Val Accuracy: 86.60%
# Epoch 32/200,  Train Loss: 0.3239,  Train Accuracy: 88.91%,  Val Loss: 0.3795,  Val Accuracy: 86.90%
# Epoch 33/200,  Train Loss: 0.3162,  Train Accuracy: 89.42%,  Val Loss: 0.3870,  Val Accuracy: 86.05%
# Epoch 34/200,  Train Loss: 0.3141,  Train Accuracy: 89.09%,  Val Loss: 0.3678,  Val Accuracy: 87.05%
# Epoch 35/200,  Train Loss: 0.3061,  Train Accuracy: 89.55%,  Val Loss: 0.3649,  Val Accuracy: 87.60%
# Epoch 36/200,  Train Loss: 0.3037,  Train Accuracy: 89.59%,  Val Loss: 0.3619,  Val Accuracy: 87.60%
# Epoch 37/200,  Train Loss: 0.3013,  Train Accuracy: 89.69%,  Val Loss: 0.3909,  Val Accuracy: 86.25%
# Epoch 38/200,  Train Loss: 0.2934,  Train Accuracy: 89.83%,  Val Loss: 0.3714,  Val Accuracy: 86.95%
# Epoch 39/200,  Train Loss: 0.2936,  Train Accuracy: 89.75%,  Val Loss: 0.3720,  Val Accuracy: 86.70%
# Epoch 40/200,  Train Loss: 0.2877,  Train Accuracy: 89.94%,  Val Loss: 0.3591,  Val Accuracy: 87.40%
# Epoch 41/200,  Train Loss: 0.2834,  Train Accuracy: 90.08%,  Val Loss: 0.3640,  Val Accuracy: 86.55%
# Epoch 42/200,  Train Loss: 0.2812,  Train Accuracy: 90.25%,  Val Loss: 0.3549,  Val Accuracy: 87.70%
# Epoch 43/200,  Train Loss: 0.2751,  Train Accuracy: 90.22%,  Val Loss: 0.3521,  Val Accuracy: 87.50%
# Epoch 44/200,  Train Loss: 0.2740,  Train Accuracy: 90.55%,  Val Loss: 0.3818,  Val Accuracy: 86.15%
# Epoch 45/200,  Train Loss: 0.2724,  Train Accuracy: 90.38%,  Val Loss: 0.3568,  Val Accuracy: 87.30%
# Epoch 46/200,  Train Loss: 0.2678,  Train Accuracy: 90.45%,  Val Loss: 0.3655,  Val Accuracy: 86.95%
# Epoch 47/200,  Train Loss: 0.2651,  Train Accuracy: 90.39%,  Val Loss: 0.3524,  Val Accuracy: 87.35%
# Epoch 48/200,  Train Loss: 0.2597,  Train Accuracy: 90.90%,  Val Loss: 0.3454,  Val Accuracy: 87.25%
# Epoch 49/200,  Train Loss: 0.2592,  Train Accuracy: 91.00%,  Val Loss: 0.3683,  Val Accuracy: 86.15%
# Epoch 50/200,  Train Loss: 0.2508,  Train Accuracy: 90.83%,  Val Loss: 0.3623,  Val Accuracy: 87.15%
# Epoch 51/200,  Train Loss: 0.2534,  Train Accuracy: 90.75%,  Val Loss: 0.3576,  Val Accuracy: 87.60%
# Epoch 52/200,  Train Loss: 0.2501,  Train Accuracy: 91.25%,  Val Loss: 0.3516,  Val Accuracy: 87.60%
# Epoch 53/200,  Train Loss: 0.2436,  Train Accuracy: 91.57%,  Val Loss: 0.3790,  Val Accuracy: 85.90%
# Epoch 00054: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 54/200,  Train Loss: 0.2413,  Train Accuracy: 91.61%,  Val Loss: 0.3545,  Val Accuracy: 87.25%
# Epoch 55/200,  Train Loss: 0.2282,  Train Accuracy: 91.92%,  Val Loss: 0.3419,  Val Accuracy: 88.05%
# Epoch 56/200,  Train Loss: 0.2219,  Train Accuracy: 92.61%,  Val Loss: 0.3446,  Val Accuracy: 87.90%
# Epoch 57/200,  Train Loss: 0.2170,  Train Accuracy: 92.53%,  Val Loss: 0.3416,  Val Accuracy: 88.00%
# Epoch 58/200,  Train Loss: 0.2166,  Train Accuracy: 92.60%,  Val Loss: 0.3414,  Val Accuracy: 87.85%
# Epoch 59/200,  Train Loss: 0.2177,  Train Accuracy: 92.65%,  Val Loss: 0.3431,  Val Accuracy: 87.85%
# Epoch 60/200,  Train Loss: 0.2165,  Train Accuracy: 92.61%,  Val Loss: 0.3423,  Val Accuracy: 87.85%
# Epoch 61/200,  Train Loss: 0.2188,  Train Accuracy: 92.64%,  Val Loss: 0.3431,  Val Accuracy: 87.50%
# Epoch 62/200,  Train Loss: 0.2176,  Train Accuracy: 92.50%,  Val Loss: 0.3433,  Val Accuracy: 87.90%
# Epoch 63/200,  Train Loss: 0.2201,  Train Accuracy: 92.44%,  Val Loss: 0.3431,  Val Accuracy: 87.80%
# Epoch 00064: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 64/200,  Train Loss: 0.2130,  Train Accuracy: 92.99%,  Val Loss: 0.3452,  Val Accuracy: 88.00%
# Epoch 65/200,  Train Loss: 0.2101,  Train Accuracy: 93.09%,  Val Loss: 0.3434,  Val Accuracy: 87.80%
# Epoch 66/200,  Train Loss: 0.2134,  Train Accuracy: 92.76%,  Val Loss: 0.3429,  Val Accuracy: 87.65%
# Epoch 67/200,  Train Loss: 0.2111,  Train Accuracy: 92.86%,  Val Loss: 0.3435,  Val Accuracy: 87.75%
# Epoch 68/200,  Train Loss: 0.2117,  Train Accuracy: 92.60%,  Val Loss: 0.3432,  Val Accuracy: 87.75%
# Stopping at epoch 68 due to no improvement in validation loss over 10 epochs.
# Results for Fold 1/5:
#  Best Epoch: 58,  Train Loss: 0.2166,  Train Accuracy: 92.60%, Val Loss: 0.3414,  Val Accuracy: 87.85%
#
# Running Fold 2/5..
# Epoch 1/200,  Train Loss: 1.2255,  Train Accuracy: 63.62%,  Val Loss: 1.0643,  Val Accuracy: 74.40%
# Epoch 2/200,  Train Loss: 1.0073,  Train Accuracy: 77.51%,  Val Loss: 0.9570,  Val Accuracy: 77.65%
# Epoch 3/200,  Train Loss: 0.9196,  Train Accuracy: 78.81%,  Val Loss: 0.8856,  Val Accuracy: 79.30%
# Epoch 4/200,  Train Loss: 0.8507,  Train Accuracy: 81.00%,  Val Loss: 0.8280,  Val Accuracy: 80.65%
# Epoch 5/200,  Train Loss: 0.7891,  Train Accuracy: 81.66%,  Val Loss: 0.7756,  Val Accuracy: 80.50%
# Epoch 6/200,  Train Loss: 0.7362,  Train Accuracy: 82.66%,  Val Loss: 0.7302,  Val Accuracy: 81.70%
# Epoch 7/200,  Train Loss: 0.6913,  Train Accuracy: 83.11%,  Val Loss: 0.6915,  Val Accuracy: 81.65%
# Epoch 8/200,  Train Loss: 0.6541,  Train Accuracy: 83.06%,  Val Loss: 0.6527,  Val Accuracy: 82.55%
# Epoch 9/200,  Train Loss: 0.6172,  Train Accuracy: 83.93%,  Val Loss: 0.6300,  Val Accuracy: 82.60%
# Epoch 10/200,  Train Loss: 0.5845,  Train Accuracy: 84.64%,  Val Loss: 0.5926,  Val Accuracy: 83.55%
# Epoch 11/200,  Train Loss: 0.5586,  Train Accuracy: 84.72%,  Val Loss: 0.5760,  Val Accuracy: 82.25%
# Epoch 12/200,  Train Loss: 0.5379,  Train Accuracy: 84.76%,  Val Loss: 0.5478,  Val Accuracy: 84.05%
# Epoch 13/200,  Train Loss: 0.5173,  Train Accuracy: 85.78%,  Val Loss: 0.5365,  Val Accuracy: 83.65%
# Epoch 14/200,  Train Loss: 0.4990,  Train Accuracy: 85.52%,  Val Loss: 0.5147,  Val Accuracy: 84.20%
# Epoch 15/200,  Train Loss: 0.4809,  Train Accuracy: 86.01%,  Val Loss: 0.5112,  Val Accuracy: 83.45%
# Epoch 16/200,  Train Loss: 0.4645,  Train Accuracy: 86.49%,  Val Loss: 0.4813,  Val Accuracy: 85.10%
# Epoch 17/200,  Train Loss: 0.4483,  Train Accuracy: 86.60%,  Val Loss: 0.4805,  Val Accuracy: 84.25%
# Epoch 18/200,  Train Loss: 0.4368,  Train Accuracy: 86.58%,  Val Loss: 0.4743,  Val Accuracy: 83.55%
# Epoch 19/200,  Train Loss: 0.4270,  Train Accuracy: 86.88%,  Val Loss: 0.4560,  Val Accuracy: 85.35%
# Epoch 20/200,  Train Loss: 0.4164,  Train Accuracy: 87.00%,  Val Loss: 0.4482,  Val Accuracy: 85.55%
# Epoch 21/200,  Train Loss: 0.4072,  Train Accuracy: 87.17%,  Val Loss: 0.4570,  Val Accuracy: 84.25%
# Epoch 22/200,  Train Loss: 0.4022,  Train Accuracy: 87.05%,  Val Loss: 0.4436,  Val Accuracy: 84.20%
# Epoch 23/200,  Train Loss: 0.3891,  Train Accuracy: 87.29%,  Val Loss: 0.4432,  Val Accuracy: 84.40%
# Epoch 24/200,  Train Loss: 0.3806,  Train Accuracy: 87.76%,  Val Loss: 0.4187,  Val Accuracy: 84.75%
# Epoch 25/200,  Train Loss: 0.3726,  Train Accuracy: 87.75%,  Val Loss: 0.4277,  Val Accuracy: 85.15%
# Epoch 26/200,  Train Loss: 0.3675,  Train Accuracy: 88.01%,  Val Loss: 0.4067,  Val Accuracy: 85.95%
# Epoch 27/200,  Train Loss: 0.3587,  Train Accuracy: 88.00%,  Val Loss: 0.4035,  Val Accuracy: 86.05%
# Epoch 28/200,  Train Loss: 0.3512,  Train Accuracy: 88.50%,  Val Loss: 0.4144,  Val Accuracy: 84.90%
# Epoch 29/200,  Train Loss: 0.3473,  Train Accuracy: 88.55%,  Val Loss: 0.3919,  Val Accuracy: 86.00%
# Epoch 30/200,  Train Loss: 0.3460,  Train Accuracy: 88.31%,  Val Loss: 0.3836,  Val Accuracy: 86.05%
# Epoch 31/200,  Train Loss: 0.3385,  Train Accuracy: 88.55%,  Val Loss: 0.3944,  Val Accuracy: 85.50%
# Epoch 32/200,  Train Loss: 0.3283,  Train Accuracy: 88.99%,  Val Loss: 0.3800,  Val Accuracy: 86.20%
# Epoch 33/200,  Train Loss: 0.3254,  Train Accuracy: 88.94%,  Val Loss: 0.3871,  Val Accuracy: 86.25%
# Epoch 34/200,  Train Loss: 0.3201,  Train Accuracy: 89.40%,  Val Loss: 0.3786,  Val Accuracy: 86.20%
# Epoch 35/200,  Train Loss: 0.3138,  Train Accuracy: 89.34%,  Val Loss: 0.3872,  Val Accuracy: 86.00%
# Epoch 36/200,  Train Loss: 0.3103,  Train Accuracy: 89.25%,  Val Loss: 0.3836,  Val Accuracy: 85.80%
# Epoch 37/200,  Train Loss: 0.3083,  Train Accuracy: 89.61%,  Val Loss: 0.3816,  Val Accuracy: 86.55%
# Epoch 38/200,  Train Loss: 0.3007,  Train Accuracy: 89.53%,  Val Loss: 0.3744,  Val Accuracy: 85.85%
# Epoch 39/200,  Train Loss: 0.2962,  Train Accuracy: 89.88%,  Val Loss: 0.3684,  Val Accuracy: 86.15%
# Epoch 40/200,  Train Loss: 0.2891,  Train Accuracy: 90.10%,  Val Loss: 0.3621,  Val Accuracy: 86.50%
# Epoch 41/200,  Train Loss: 0.2870,  Train Accuracy: 90.09%,  Val Loss: 0.3683,  Val Accuracy: 86.65%
# Epoch 42/200,  Train Loss: 0.2858,  Train Accuracy: 89.91%,  Val Loss: 0.3747,  Val Accuracy: 85.45%
# Epoch 43/200,  Train Loss: 0.2787,  Train Accuracy: 90.48%,  Val Loss: 0.3616,  Val Accuracy: 86.85%
# Epoch 44/200,  Train Loss: 0.2753,  Train Accuracy: 90.44%,  Val Loss: 0.3753,  Val Accuracy: 85.25%
# Epoch 45/200,  Train Loss: 0.2794,  Train Accuracy: 90.16%,  Val Loss: 0.3674,  Val Accuracy: 85.65%
# Epoch 46/200,  Train Loss: 0.2685,  Train Accuracy: 90.55%,  Val Loss: 0.3654,  Val Accuracy: 85.70%
# Epoch 47/200,  Train Loss: 0.2682,  Train Accuracy: 90.85%,  Val Loss: 0.3516,  Val Accuracy: 86.70%
# Epoch 48/200,  Train Loss: 0.2625,  Train Accuracy: 90.72%,  Val Loss: 0.3794,  Val Accuracy: 85.60%
# Epoch 49/200,  Train Loss: 0.2594,  Train Accuracy: 90.97%,  Val Loss: 0.3529,  Val Accuracy: 86.45%
# Epoch 50/200,  Train Loss: 0.2637,  Train Accuracy: 90.60%,  Val Loss: 0.3583,  Val Accuracy: 86.70%
# Epoch 51/200,  Train Loss: 0.2502,  Train Accuracy: 91.34%,  Val Loss: 0.3612,  Val Accuracy: 85.80%
# Epoch 52/200,  Train Loss: 0.2509,  Train Accuracy: 91.33%,  Val Loss: 0.3424,  Val Accuracy: 87.05%
# Epoch 53/200,  Train Loss: 0.2422,  Train Accuracy: 91.59%,  Val Loss: 0.3592,  Val Accuracy: 86.35%
# Epoch 54/200,  Train Loss: 0.2446,  Train Accuracy: 91.54%,  Val Loss: 0.3669,  Val Accuracy: 86.10%
# Epoch 55/200,  Train Loss: 0.2390,  Train Accuracy: 91.70%,  Val Loss: 0.3790,  Val Accuracy: 86.00%
# Epoch 56/200,  Train Loss: 0.2368,  Train Accuracy: 91.81%,  Val Loss: 0.3596,  Val Accuracy: 86.00%
# Epoch 57/200,  Train Loss: 0.2333,  Train Accuracy: 91.97%,  Val Loss: 0.3495,  Val Accuracy: 86.55%
# Epoch 00058: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 58/200,  Train Loss: 0.2357,  Train Accuracy: 91.81%,  Val Loss: 0.3512,  Val Accuracy: 86.80%
# Epoch 59/200,  Train Loss: 0.2146,  Train Accuracy: 92.75%,  Val Loss: 0.3341,  Val Accuracy: 87.30%
# Epoch 60/200,  Train Loss: 0.2107,  Train Accuracy: 92.96%,  Val Loss: 0.3333,  Val Accuracy: 87.10%
# Epoch 61/200,  Train Loss: 0.2112,  Train Accuracy: 93.08%,  Val Loss: 0.3335,  Val Accuracy: 87.35%
# Epoch 62/200,  Train Loss: 0.2051,  Train Accuracy: 93.44%,  Val Loss: 0.3340,  Val Accuracy: 87.10%
# Epoch 63/200,  Train Loss: 0.2069,  Train Accuracy: 93.21%,  Val Loss: 0.3338,  Val Accuracy: 87.20%
# Epoch 64/200,  Train Loss: 0.2075,  Train Accuracy: 93.31%,  Val Loss: 0.3326,  Val Accuracy: 87.25%
# Epoch 65/200,  Train Loss: 0.2063,  Train Accuracy: 93.11%,  Val Loss: 0.3323,  Val Accuracy: 87.25%
# Epoch 66/200,  Train Loss: 0.2058,  Train Accuracy: 93.26%,  Val Loss: 0.3339,  Val Accuracy: 87.15%
# Epoch 67/200,  Train Loss: 0.2063,  Train Accuracy: 93.26%,  Val Loss: 0.3319,  Val Accuracy: 87.30%
# Epoch 68/200,  Train Loss: 0.2052,  Train Accuracy: 93.11%,  Val Loss: 0.3312,  Val Accuracy: 87.25%
# Epoch 69/200,  Train Loss: 0.2041,  Train Accuracy: 93.10%,  Val Loss: 0.3321,  Val Accuracy: 86.90%
# Epoch 70/200,  Train Loss: 0.2064,  Train Accuracy: 92.97%,  Val Loss: 0.3341,  Val Accuracy: 87.25%
# Epoch 71/200,  Train Loss: 0.2005,  Train Accuracy: 93.21%,  Val Loss: 0.3311,  Val Accuracy: 87.40%
# Epoch 72/200,  Train Loss: 0.2023,  Train Accuracy: 93.10%,  Val Loss: 0.3336,  Val Accuracy: 87.25%
# Epoch 73/200,  Train Loss: 0.2047,  Train Accuracy: 93.09%,  Val Loss: 0.3311,  Val Accuracy: 87.50%
# Epoch 74/200,  Train Loss: 0.2013,  Train Accuracy: 93.58%,  Val Loss: 0.3332,  Val Accuracy: 87.10%
# Epoch 75/200,  Train Loss: 0.2012,  Train Accuracy: 93.46%,  Val Loss: 0.3308,  Val Accuracy: 87.25%
# Epoch 76/200,  Train Loss: 0.1988,  Train Accuracy: 93.60%,  Val Loss: 0.3326,  Val Accuracy: 87.20%
# Epoch 77/200,  Train Loss: 0.2003,  Train Accuracy: 93.46%,  Val Loss: 0.3306,  Val Accuracy: 87.05%
# Epoch 78/200,  Train Loss: 0.2036,  Train Accuracy: 93.50%,  Val Loss: 0.3321,  Val Accuracy: 87.15%
# Epoch 79/200,  Train Loss: 0.2012,  Train Accuracy: 93.25%,  Val Loss: 0.3307,  Val Accuracy: 87.30%
# Epoch 80/200,  Train Loss: 0.2020,  Train Accuracy: 93.27%,  Val Loss: 0.3315,  Val Accuracy: 87.25%
# Epoch 81/200,  Train Loss: 0.1999,  Train Accuracy: 93.56%,  Val Loss: 0.3340,  Val Accuracy: 86.85%
# Epoch 82/200,  Train Loss: 0.2010,  Train Accuracy: 93.55%,  Val Loss: 0.3303,  Val Accuracy: 87.60%
# Epoch 83/200,  Train Loss: 0.2008,  Train Accuracy: 93.30%,  Val Loss: 0.3316,  Val Accuracy: 87.25%
# Epoch 84/200,  Train Loss: 0.1965,  Train Accuracy: 93.64%,  Val Loss: 0.3301,  Val Accuracy: 87.50%
# Epoch 85/200,  Train Loss: 0.1997,  Train Accuracy: 93.61%,  Val Loss: 0.3300,  Val Accuracy: 87.75%
# Epoch 86/200,  Train Loss: 0.1993,  Train Accuracy: 93.39%,  Val Loss: 0.3316,  Val Accuracy: 87.25%
# Epoch 87/200,  Train Loss: 0.1945,  Train Accuracy: 93.58%,  Val Loss: 0.3298,  Val Accuracy: 87.30%
# Epoch 88/200,  Train Loss: 0.1960,  Train Accuracy: 93.62%,  Val Loss: 0.3302,  Val Accuracy: 87.25%
# Epoch 89/200,  Train Loss: 0.1974,  Train Accuracy: 93.55%,  Val Loss: 0.3311,  Val Accuracy: 87.50%
# Epoch 90/200,  Train Loss: 0.1946,  Train Accuracy: 93.77%,  Val Loss: 0.3333,  Val Accuracy: 87.20%
# Epoch 91/200,  Train Loss: 0.1970,  Train Accuracy: 93.39%,  Val Loss: 0.3319,  Val Accuracy: 87.10%
# Epoch 92/200,  Train Loss: 0.1933,  Train Accuracy: 93.67%,  Val Loss: 0.3319,  Val Accuracy: 87.10%
# Epoch 00093: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 93/200,  Train Loss: 0.1985,  Train Accuracy: 93.58%,  Val Loss: 0.3301,  Val Accuracy: 87.65%
# Epoch 94/200,  Train Loss: 0.1925,  Train Accuracy: 93.56%,  Val Loss: 0.3285,  Val Accuracy: 87.35%
# Epoch 95/200,  Train Loss: 0.1934,  Train Accuracy: 93.94%,  Val Loss: 0.3295,  Val Accuracy: 87.35%
# Epoch 96/200,  Train Loss: 0.1936,  Train Accuracy: 93.71%,  Val Loss: 0.3293,  Val Accuracy: 87.40%
# Epoch 97/200,  Train Loss: 0.1901,  Train Accuracy: 93.81%,  Val Loss: 0.3296,  Val Accuracy: 87.40%
# Epoch 98/200,  Train Loss: 0.1927,  Train Accuracy: 93.73%,  Val Loss: 0.3315,  Val Accuracy: 87.15%
# Epoch 99/200,  Train Loss: 0.1917,  Train Accuracy: 93.56%,  Val Loss: 0.3303,  Val Accuracy: 87.25%
# Epoch 00100: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 100/200,  Train Loss: 0.1944,  Train Accuracy: 93.75%,  Val Loss: 0.3307,  Val Accuracy: 87.15%
# Epoch 101/200,  Train Loss: 0.1924,  Train Accuracy: 93.89%,  Val Loss: 0.3313,  Val Accuracy: 87.25%
# Epoch 102/200,  Train Loss: 0.1928,  Train Accuracy: 93.64%,  Val Loss: 0.3310,  Val Accuracy: 87.30%
# Epoch 103/200,  Train Loss: 0.1928,  Train Accuracy: 93.79%,  Val Loss: 0.3295,  Val Accuracy: 87.40%
# Epoch 104/200,  Train Loss: 0.1899,  Train Accuracy: 94.14%,  Val Loss: 0.3304,  Val Accuracy: 87.20%
# Stopping at epoch 104 due to no improvement in validation loss over 10 epochs.
# Results for Fold 2/5:
#  Best Epoch: 94,  Train Loss: 0.1925,  Train Accuracy: 93.56%, Val Loss: 0.3285,  Val Accuracy: 87.35%
#
# Running Fold 3/5..
# Epoch 1/200,  Train Loss: 1.2211,  Train Accuracy: 63.88%,  Val Loss: 1.0563,  Val Accuracy: 75.50%
# Epoch 2/200,  Train Loss: 1.0061,  Train Accuracy: 77.40%,  Val Loss: 0.9483,  Val Accuracy: 79.45%
# Epoch 3/200,  Train Loss: 0.9179,  Train Accuracy: 79.41%,  Val Loss: 0.8673,  Val Accuracy: 81.50%
# Epoch 4/200,  Train Loss: 0.8485,  Train Accuracy: 80.38%,  Val Loss: 0.8039,  Val Accuracy: 82.00%
# Epoch 5/200,  Train Loss: 0.7901,  Train Accuracy: 81.08%,  Val Loss: 0.7515,  Val Accuracy: 82.35%
# Epoch 6/200,  Train Loss: 0.7386,  Train Accuracy: 82.21%,  Val Loss: 0.7016,  Val Accuracy: 82.95%
# Epoch 7/200,  Train Loss: 0.6942,  Train Accuracy: 82.55%,  Val Loss: 0.6650,  Val Accuracy: 82.95%
# Epoch 8/200,  Train Loss: 0.6567,  Train Accuracy: 83.10%,  Val Loss: 0.6307,  Val Accuracy: 83.60%
# Epoch 9/200,  Train Loss: 0.6215,  Train Accuracy: 83.85%,  Val Loss: 0.6031,  Val Accuracy: 83.55%
# Epoch 10/200,  Train Loss: 0.5910,  Train Accuracy: 84.15%,  Val Loss: 0.5752,  Val Accuracy: 83.90%
# Epoch 11/200,  Train Loss: 0.5688,  Train Accuracy: 84.26%,  Val Loss: 0.5526,  Val Accuracy: 85.20%
# Epoch 12/200,  Train Loss: 0.5406,  Train Accuracy: 85.08%,  Val Loss: 0.5289,  Val Accuracy: 84.95%
# Epoch 13/200,  Train Loss: 0.5194,  Train Accuracy: 85.14%,  Val Loss: 0.5130,  Val Accuracy: 85.20%
# Epoch 14/200,  Train Loss: 0.5013,  Train Accuracy: 85.22%,  Val Loss: 0.5037,  Val Accuracy: 86.20%
# Epoch 15/200,  Train Loss: 0.4835,  Train Accuracy: 85.64%,  Val Loss: 0.4719,  Val Accuracy: 86.25%
# Epoch 16/200,  Train Loss: 0.4673,  Train Accuracy: 85.69%,  Val Loss: 0.4623,  Val Accuracy: 86.40%
# Epoch 17/200,  Train Loss: 0.4531,  Train Accuracy: 86.48%,  Val Loss: 0.4533,  Val Accuracy: 86.85%
# Epoch 18/200,  Train Loss: 0.4401,  Train Accuracy: 86.69%,  Val Loss: 0.4373,  Val Accuracy: 86.50%
# Epoch 19/200,  Train Loss: 0.4261,  Train Accuracy: 86.84%,  Val Loss: 0.4453,  Val Accuracy: 86.15%
# Epoch 20/200,  Train Loss: 0.4185,  Train Accuracy: 86.90%,  Val Loss: 0.4222,  Val Accuracy: 85.70%
# Epoch 21/200,  Train Loss: 0.4063,  Train Accuracy: 87.31%,  Val Loss: 0.4192,  Val Accuracy: 87.30%
# Epoch 22/200,  Train Loss: 0.3951,  Train Accuracy: 87.54%,  Val Loss: 0.4197,  Val Accuracy: 86.90%
# Epoch 23/200,  Train Loss: 0.3853,  Train Accuracy: 87.50%,  Val Loss: 0.3984,  Val Accuracy: 86.90%
# Epoch 24/200,  Train Loss: 0.3794,  Train Accuracy: 87.85%,  Val Loss: 0.3920,  Val Accuracy: 87.60%
# Epoch 25/200,  Train Loss: 0.3687,  Train Accuracy: 88.35%,  Val Loss: 0.3940,  Val Accuracy: 87.00%
# Epoch 26/200,  Train Loss: 0.3616,  Train Accuracy: 88.26%,  Val Loss: 0.3790,  Val Accuracy: 87.25%
# Epoch 27/200,  Train Loss: 0.3608,  Train Accuracy: 87.86%,  Val Loss: 0.3962,  Val Accuracy: 86.25%
# Epoch 28/200,  Train Loss: 0.3485,  Train Accuracy: 88.20%,  Val Loss: 0.3753,  Val Accuracy: 87.60%
# Epoch 29/200,  Train Loss: 0.3360,  Train Accuracy: 88.67%,  Val Loss: 0.3716,  Val Accuracy: 87.60%
# Epoch 30/200,  Train Loss: 0.3383,  Train Accuracy: 88.10%,  Val Loss: 0.3802,  Val Accuracy: 87.50%
# Epoch 31/200,  Train Loss: 0.3313,  Train Accuracy: 88.76%,  Val Loss: 0.3712,  Val Accuracy: 87.40%
# Epoch 32/200,  Train Loss: 0.3268,  Train Accuracy: 88.86%,  Val Loss: 0.3816,  Val Accuracy: 87.15%
# Epoch 33/200,  Train Loss: 0.3219,  Train Accuracy: 89.05%,  Val Loss: 0.3821,  Val Accuracy: 86.55%
# Epoch 34/200,  Train Loss: 0.3181,  Train Accuracy: 89.09%,  Val Loss: 0.3662,  Val Accuracy: 86.95%
# Epoch 35/200,  Train Loss: 0.3121,  Train Accuracy: 89.35%,  Val Loss: 0.3905,  Val Accuracy: 86.10%
# Epoch 36/200,  Train Loss: 0.3091,  Train Accuracy: 89.40%,  Val Loss: 0.3799,  Val Accuracy: 86.35%
# Epoch 37/200,  Train Loss: 0.3046,  Train Accuracy: 89.55%,  Val Loss: 0.3478,  Val Accuracy: 88.15%
# Epoch 38/200,  Train Loss: 0.3011,  Train Accuracy: 89.56%,  Val Loss: 0.3895,  Val Accuracy: 85.85%
# Epoch 39/200,  Train Loss: 0.2939,  Train Accuracy: 89.69%,  Val Loss: 0.3594,  Val Accuracy: 87.40%
# Epoch 40/200,  Train Loss: 0.2885,  Train Accuracy: 90.25%,  Val Loss: 0.3745,  Val Accuracy: 86.75%
# Epoch 41/200,  Train Loss: 0.2839,  Train Accuracy: 90.15%,  Val Loss: 0.3520,  Val Accuracy: 87.45%
# Epoch 42/200,  Train Loss: 0.2793,  Train Accuracy: 90.21%,  Val Loss: 0.3517,  Val Accuracy: 87.15%
# Epoch 00043: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 43/200,  Train Loss: 0.2746,  Train Accuracy: 90.64%,  Val Loss: 0.3494,  Val Accuracy: 88.15%
# Epoch 44/200,  Train Loss: 0.2595,  Train Accuracy: 91.04%,  Val Loss: 0.3380,  Val Accuracy: 88.35%
# Epoch 45/200,  Train Loss: 0.2562,  Train Accuracy: 91.44%,  Val Loss: 0.3401,  Val Accuracy: 88.20%
# Epoch 46/200,  Train Loss: 0.2547,  Train Accuracy: 91.57%,  Val Loss: 0.3425,  Val Accuracy: 87.90%
# Epoch 47/200,  Train Loss: 0.2539,  Train Accuracy: 91.39%,  Val Loss: 0.3393,  Val Accuracy: 88.20%
# Epoch 48/200,  Train Loss: 0.2540,  Train Accuracy: 91.51%,  Val Loss: 0.3393,  Val Accuracy: 88.20%
# Epoch 49/200,  Train Loss: 0.2509,  Train Accuracy: 91.47%,  Val Loss: 0.3405,  Val Accuracy: 88.30%
# Epoch 00050: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 50/200,  Train Loss: 0.2516,  Train Accuracy: 91.46%,  Val Loss: 0.3404,  Val Accuracy: 87.90%
# Epoch 51/200,  Train Loss: 0.2478,  Train Accuracy: 91.89%,  Val Loss: 0.3400,  Val Accuracy: 88.15%
# Epoch 52/200,  Train Loss: 0.2462,  Train Accuracy: 91.62%,  Val Loss: 0.3410,  Val Accuracy: 88.15%
# Epoch 53/200,  Train Loss: 0.2460,  Train Accuracy: 92.05%,  Val Loss: 0.3390,  Val Accuracy: 88.35%
# Epoch 54/200,  Train Loss: 0.2502,  Train Accuracy: 91.81%,  Val Loss: 0.3389,  Val Accuracy: 87.95%
# Stopping at epoch 54 due to no improvement in validation loss over 10 epochs.
# Results for Fold 3/5:
#  Best Epoch: 44,  Train Loss: 0.2595,  Train Accuracy: 91.04%, Val Loss: 0.3380,  Val Accuracy: 88.35%
#
# Running Fold 4/5..
# Epoch 1/200,  Train Loss: 1.2293,  Train Accuracy: 63.20%,  Val Loss: 1.0663,  Val Accuracy: 76.60%
# Epoch 2/200,  Train Loss: 1.0082,  Train Accuracy: 76.98%,  Val Loss: 0.9634,  Val Accuracy: 77.75%
# Epoch 3/200,  Train Loss: 0.9199,  Train Accuracy: 79.12%,  Val Loss: 0.8838,  Val Accuracy: 79.80%
# Epoch 4/200,  Train Loss: 0.8501,  Train Accuracy: 80.24%,  Val Loss: 0.8309,  Val Accuracy: 80.50%
# Epoch 5/200,  Train Loss: 0.7920,  Train Accuracy: 80.85%,  Val Loss: 0.7742,  Val Accuracy: 80.75%
# Epoch 6/200,  Train Loss: 0.7400,  Train Accuracy: 81.90%,  Val Loss: 0.7243,  Val Accuracy: 82.25%
# Epoch 7/200,  Train Loss: 0.6961,  Train Accuracy: 82.45%,  Val Loss: 0.6880,  Val Accuracy: 82.25%
# Epoch 8/200,  Train Loss: 0.6569,  Train Accuracy: 82.70%,  Val Loss: 0.6510,  Val Accuracy: 82.10%
# Epoch 9/200,  Train Loss: 0.6239,  Train Accuracy: 83.40%,  Val Loss: 0.6265,  Val Accuracy: 82.10%
# Epoch 10/200,  Train Loss: 0.5944,  Train Accuracy: 83.67%,  Val Loss: 0.5954,  Val Accuracy: 83.65%
# Epoch 11/200,  Train Loss: 0.5678,  Train Accuracy: 84.20%,  Val Loss: 0.5843,  Val Accuracy: 82.65%
# Epoch 12/200,  Train Loss: 0.5448,  Train Accuracy: 84.42%,  Val Loss: 0.5591,  Val Accuracy: 84.20%
# Epoch 13/200,  Train Loss: 0.5250,  Train Accuracy: 85.01%,  Val Loss: 0.5383,  Val Accuracy: 84.00%
# Epoch 14/200,  Train Loss: 0.5051,  Train Accuracy: 85.29%,  Val Loss: 0.5291,  Val Accuracy: 83.75%
# Epoch 15/200,  Train Loss: 0.4874,  Train Accuracy: 85.47%,  Val Loss: 0.5199,  Val Accuracy: 83.80%
# Epoch 16/200,  Train Loss: 0.4723,  Train Accuracy: 85.51%,  Val Loss: 0.4882,  Val Accuracy: 84.75%
# Epoch 17/200,  Train Loss: 0.4564,  Train Accuracy: 86.29%,  Val Loss: 0.4793,  Val Accuracy: 84.80%
# Epoch 18/200,  Train Loss: 0.4467,  Train Accuracy: 85.86%,  Val Loss: 0.4861,  Val Accuracy: 84.20%
# Epoch 19/200,  Train Loss: 0.4340,  Train Accuracy: 86.21%,  Val Loss: 0.4803,  Val Accuracy: 84.35%
# Epoch 20/200,  Train Loss: 0.4252,  Train Accuracy: 86.60%,  Val Loss: 0.4483,  Val Accuracy: 84.85%
# Epoch 21/200,  Train Loss: 0.4141,  Train Accuracy: 86.76%,  Val Loss: 0.4478,  Val Accuracy: 85.40%
# Epoch 22/200,  Train Loss: 0.4061,  Train Accuracy: 86.88%,  Val Loss: 0.4451,  Val Accuracy: 85.15%
# Epoch 23/200,  Train Loss: 0.3938,  Train Accuracy: 87.29%,  Val Loss: 0.4331,  Val Accuracy: 84.90%
# Epoch 24/200,  Train Loss: 0.3897,  Train Accuracy: 87.34%,  Val Loss: 0.4350,  Val Accuracy: 85.60%
# Epoch 25/200,  Train Loss: 0.3808,  Train Accuracy: 87.49%,  Val Loss: 0.4212,  Val Accuracy: 85.40%
# Epoch 26/200,  Train Loss: 0.3760,  Train Accuracy: 87.62%,  Val Loss: 0.4125,  Val Accuracy: 86.30%
# Epoch 27/200,  Train Loss: 0.3677,  Train Accuracy: 87.67%,  Val Loss: 0.4168,  Val Accuracy: 86.00%
# Epoch 28/200,  Train Loss: 0.3583,  Train Accuracy: 88.08%,  Val Loss: 0.4133,  Val Accuracy: 85.70%
# Epoch 29/200,  Train Loss: 0.3493,  Train Accuracy: 88.44%,  Val Loss: 0.4028,  Val Accuracy: 86.05%
# Epoch 30/200,  Train Loss: 0.3485,  Train Accuracy: 88.05%,  Val Loss: 0.3976,  Val Accuracy: 86.70%
# Epoch 31/200,  Train Loss: 0.3432,  Train Accuracy: 88.42%,  Val Loss: 0.3896,  Val Accuracy: 86.30%
# Epoch 32/200,  Train Loss: 0.3347,  Train Accuracy: 88.44%,  Val Loss: 0.3894,  Val Accuracy: 86.30%
# Epoch 33/200,  Train Loss: 0.3309,  Train Accuracy: 88.83%,  Val Loss: 0.4200,  Val Accuracy: 85.10%
# Epoch 34/200,  Train Loss: 0.3275,  Train Accuracy: 89.24%,  Val Loss: 0.4026,  Val Accuracy: 85.75%
# Epoch 35/200,  Train Loss: 0.3194,  Train Accuracy: 88.98%,  Val Loss: 0.3781,  Val Accuracy: 86.85%
# Epoch 36/200,  Train Loss: 0.3140,  Train Accuracy: 89.42%,  Val Loss: 0.3825,  Val Accuracy: 86.60%
# Epoch 37/200,  Train Loss: 0.3176,  Train Accuracy: 88.94%,  Val Loss: 0.4027,  Val Accuracy: 85.35%
# Epoch 38/200,  Train Loss: 0.3123,  Train Accuracy: 89.25%,  Val Loss: 0.3986,  Val Accuracy: 86.20%
# Epoch 39/200,  Train Loss: 0.3031,  Train Accuracy: 89.60%,  Val Loss: 0.3935,  Val Accuracy: 85.55%
# Epoch 40/200,  Train Loss: 0.2960,  Train Accuracy: 89.76%,  Val Loss: 0.3878,  Val Accuracy: 86.10%
# Epoch 41/200,  Train Loss: 0.2914,  Train Accuracy: 90.04%,  Val Loss: 0.3691,  Val Accuracy: 87.05%
# Epoch 42/200,  Train Loss: 0.2934,  Train Accuracy: 89.90%,  Val Loss: 0.3795,  Val Accuracy: 86.70%
# Epoch 43/200,  Train Loss: 0.2866,  Train Accuracy: 90.09%,  Val Loss: 0.3822,  Val Accuracy: 85.95%
# Epoch 44/200,  Train Loss: 0.2824,  Train Accuracy: 90.09%,  Val Loss: 0.3696,  Val Accuracy: 87.10%
# Epoch 45/200,  Train Loss: 0.2811,  Train Accuracy: 90.14%,  Val Loss: 0.3729,  Val Accuracy: 87.00%
# Epoch 46/200,  Train Loss: 0.2760,  Train Accuracy: 90.59%,  Val Loss: 0.3835,  Val Accuracy: 86.20%
# Epoch 00047: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 47/200,  Train Loss: 0.2735,  Train Accuracy: 90.51%,  Val Loss: 0.3810,  Val Accuracy: 86.25%
# Epoch 48/200,  Train Loss: 0.2567,  Train Accuracy: 91.51%,  Val Loss: 0.3551,  Val Accuracy: 87.45%
# Epoch 49/200,  Train Loss: 0.2514,  Train Accuracy: 91.75%,  Val Loss: 0.3580,  Val Accuracy: 87.35%
# Epoch 50/200,  Train Loss: 0.2507,  Train Accuracy: 91.72%,  Val Loss: 0.3562,  Val Accuracy: 87.35%
# Epoch 51/200,  Train Loss: 0.2491,  Train Accuracy: 91.89%,  Val Loss: 0.3576,  Val Accuracy: 87.05%
# Epoch 52/200,  Train Loss: 0.2510,  Train Accuracy: 91.79%,  Val Loss: 0.3579,  Val Accuracy: 87.20%
# Epoch 53/200,  Train Loss: 0.2491,  Train Accuracy: 91.83%,  Val Loss: 0.3563,  Val Accuracy: 87.10%
# Epoch 00054: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 54/200,  Train Loss: 0.2473,  Train Accuracy: 91.76%,  Val Loss: 0.3570,  Val Accuracy: 87.05%
# Epoch 55/200,  Train Loss: 0.2459,  Train Accuracy: 91.84%,  Val Loss: 0.3587,  Val Accuracy: 87.50%
# Epoch 56/200,  Train Loss: 0.2474,  Train Accuracy: 91.85%,  Val Loss: 0.3565,  Val Accuracy: 87.20%
# Epoch 57/200,  Train Loss: 0.2481,  Train Accuracy: 91.92%,  Val Loss: 0.3567,  Val Accuracy: 87.10%
# Epoch 58/200,  Train Loss: 0.2467,  Train Accuracy: 91.89%,  Val Loss: 0.3563,  Val Accuracy: 87.40%
# Stopping at epoch 58 due to no improvement in validation loss over 10 epochs.
# Results for Fold 4/5:
#  Best Epoch: 48,  Train Loss: 0.2567,  Train Accuracy: 91.51%, Val Loss: 0.3551,  Val Accuracy: 87.45%
#
# Running Fold 5/5..
# Epoch 1/200,  Train Loss: 1.2237,  Train Accuracy: 64.68%,  Val Loss: 1.0472,  Val Accuracy: 76.10%
# Epoch 2/200,  Train Loss: 0.9996,  Train Accuracy: 76.60%,  Val Loss: 0.9438,  Val Accuracy: 78.05%
# Epoch 3/200,  Train Loss: 0.9072,  Train Accuracy: 79.54%,  Val Loss: 0.8622,  Val Accuracy: 79.80%
# Epoch 4/200,  Train Loss: 0.8367,  Train Accuracy: 80.54%,  Val Loss: 0.8084,  Val Accuracy: 81.15%
# Epoch 5/200,  Train Loss: 0.7781,  Train Accuracy: 81.42%,  Val Loss: 0.7530,  Val Accuracy: 81.50%
# Epoch 6/200,  Train Loss: 0.7249,  Train Accuracy: 82.74%,  Val Loss: 0.6992,  Val Accuracy: 81.40%
# Epoch 7/200,  Train Loss: 0.6813,  Train Accuracy: 83.30%,  Val Loss: 0.6671,  Val Accuracy: 82.25%
# Epoch 8/200,  Train Loss: 0.6425,  Train Accuracy: 83.85%,  Val Loss: 0.6298,  Val Accuracy: 82.55%
# Epoch 9/200,  Train Loss: 0.6086,  Train Accuracy: 84.39%,  Val Loss: 0.6194,  Val Accuracy: 82.70%
# Epoch 10/200,  Train Loss: 0.5812,  Train Accuracy: 84.44%,  Val Loss: 0.5806,  Val Accuracy: 83.40%
# Epoch 11/200,  Train Loss: 0.5549,  Train Accuracy: 84.81%,  Val Loss: 0.5465,  Val Accuracy: 83.45%
# Epoch 12/200,  Train Loss: 0.5299,  Train Accuracy: 85.47%,  Val Loss: 0.5285,  Val Accuracy: 83.80%
# Epoch 13/200,  Train Loss: 0.5109,  Train Accuracy: 85.40%,  Val Loss: 0.5120,  Val Accuracy: 84.05%
# Epoch 14/200,  Train Loss: 0.4918,  Train Accuracy: 85.84%,  Val Loss: 0.4905,  Val Accuracy: 84.30%
# Epoch 15/200,  Train Loss: 0.4745,  Train Accuracy: 86.24%,  Val Loss: 0.4921,  Val Accuracy: 84.55%
# Epoch 16/200,  Train Loss: 0.4578,  Train Accuracy: 86.78%,  Val Loss: 0.5012,  Val Accuracy: 83.75%
# Epoch 17/200,  Train Loss: 0.4443,  Train Accuracy: 86.72%,  Val Loss: 0.4594,  Val Accuracy: 85.20%
# Epoch 18/200,  Train Loss: 0.4288,  Train Accuracy: 87.20%,  Val Loss: 0.4576,  Val Accuracy: 84.35%
# Epoch 19/200,  Train Loss: 0.4218,  Train Accuracy: 87.24%,  Val Loss: 0.4494,  Val Accuracy: 84.05%
# Epoch 20/200,  Train Loss: 0.4101,  Train Accuracy: 87.36%,  Val Loss: 0.4353,  Val Accuracy: 84.95%
# Epoch 21/200,  Train Loss: 0.3977,  Train Accuracy: 87.60%,  Val Loss: 0.4373,  Val Accuracy: 84.70%
# Epoch 22/200,  Train Loss: 0.3873,  Train Accuracy: 87.98%,  Val Loss: 0.4260,  Val Accuracy: 85.30%
# Epoch 23/200,  Train Loss: 0.3810,  Train Accuracy: 88.15%,  Val Loss: 0.4341,  Val Accuracy: 83.90%
# Epoch 24/200,  Train Loss: 0.3700,  Train Accuracy: 88.38%,  Val Loss: 0.4124,  Val Accuracy: 85.30%
# Epoch 25/200,  Train Loss: 0.3656,  Train Accuracy: 88.09%,  Val Loss: 0.4163,  Val Accuracy: 85.00%
# Epoch 26/200,  Train Loss: 0.3550,  Train Accuracy: 88.58%,  Val Loss: 0.4074,  Val Accuracy: 85.45%
# Epoch 27/200,  Train Loss: 0.3477,  Train Accuracy: 88.50%,  Val Loss: 0.3973,  Val Accuracy: 86.00%
# Epoch 28/200,  Train Loss: 0.3421,  Train Accuracy: 88.67%,  Val Loss: 0.4096,  Val Accuracy: 85.50%
# Epoch 29/200,  Train Loss: 0.3364,  Train Accuracy: 89.01%,  Val Loss: 0.3873,  Val Accuracy: 85.75%
# Epoch 30/200,  Train Loss: 0.3292,  Train Accuracy: 89.08%,  Val Loss: 0.3973,  Val Accuracy: 86.05%
# Epoch 31/200,  Train Loss: 0.3248,  Train Accuracy: 89.10%,  Val Loss: 0.3981,  Val Accuracy: 85.25%
# Epoch 32/200,  Train Loss: 0.3244,  Train Accuracy: 89.68%,  Val Loss: 0.3782,  Val Accuracy: 85.85%
# Epoch 33/200,  Train Loss: 0.3110,  Train Accuracy: 89.69%,  Val Loss: 0.4046,  Val Accuracy: 84.55%
# Epoch 34/200,  Train Loss: 0.3096,  Train Accuracy: 89.72%,  Val Loss: 0.3803,  Val Accuracy: 85.80%
# Epoch 35/200,  Train Loss: 0.3072,  Train Accuracy: 89.58%,  Val Loss: 0.3720,  Val Accuracy: 86.25%
# Epoch 36/200,  Train Loss: 0.2989,  Train Accuracy: 90.01%,  Val Loss: 0.3720,  Val Accuracy: 86.10%
# Epoch 37/200,  Train Loss: 0.2944,  Train Accuracy: 89.74%,  Val Loss: 0.3713,  Val Accuracy: 86.45%
# Epoch 38/200,  Train Loss: 0.2863,  Train Accuracy: 90.56%,  Val Loss: 0.3861,  Val Accuracy: 85.40%
# Epoch 39/200,  Train Loss: 0.2929,  Train Accuracy: 89.75%,  Val Loss: 0.3705,  Val Accuracy: 86.15%
# Epoch 40/200,  Train Loss: 0.2827,  Train Accuracy: 90.58%,  Val Loss: 0.4374,  Val Accuracy: 83.95%
# Epoch 41/200,  Train Loss: 0.2774,  Train Accuracy: 90.51%,  Val Loss: 0.3684,  Val Accuracy: 86.00%
# Epoch 42/200,  Train Loss: 0.2782,  Train Accuracy: 90.67%,  Val Loss: 0.3714,  Val Accuracy: 86.00%
# Epoch 43/200,  Train Loss: 0.2700,  Train Accuracy: 91.06%,  Val Loss: 0.3683,  Val Accuracy: 86.00%
# Epoch 44/200,  Train Loss: 0.2730,  Train Accuracy: 90.41%,  Val Loss: 0.3777,  Val Accuracy: 86.10%
# Epoch 45/200,  Train Loss: 0.2648,  Train Accuracy: 90.94%,  Val Loss: 0.3819,  Val Accuracy: 85.65%
# Epoch 46/200,  Train Loss: 0.2577,  Train Accuracy: 91.07%,  Val Loss: 0.3966,  Val Accuracy: 85.00%
# Epoch 47/200,  Train Loss: 0.2560,  Train Accuracy: 91.11%,  Val Loss: 0.3739,  Val Accuracy: 85.65%
# Epoch 48/200,  Train Loss: 0.2537,  Train Accuracy: 91.20%,  Val Loss: 0.3739,  Val Accuracy: 86.25%
# Epoch 49/200,  Train Loss: 0.2540,  Train Accuracy: 91.15%,  Val Loss: 0.3630,  Val Accuracy: 86.65%
# Epoch 50/200,  Train Loss: 0.2450,  Train Accuracy: 91.79%,  Val Loss: 0.3680,  Val Accuracy: 85.70%
# Epoch 51/200,  Train Loss: 0.2428,  Train Accuracy: 91.75%,  Val Loss: 0.3608,  Val Accuracy: 86.35%
# Epoch 52/200,  Train Loss: 0.2448,  Train Accuracy: 91.47%,  Val Loss: 0.3640,  Val Accuracy: 86.55%
# Epoch 53/200,  Train Loss: 0.2409,  Train Accuracy: 91.56%,  Val Loss: 0.3792,  Val Accuracy: 85.40%
# Epoch 54/200,  Train Loss: 0.2345,  Train Accuracy: 92.01%,  Val Loss: 0.3675,  Val Accuracy: 85.65%
# Epoch 55/200,  Train Loss: 0.2327,  Train Accuracy: 92.04%,  Val Loss: 0.3512,  Val Accuracy: 86.80%
# Epoch 56/200,  Train Loss: 0.2287,  Train Accuracy: 92.07%,  Val Loss: 0.3897,  Val Accuracy: 85.05%
# Epoch 57/200,  Train Loss: 0.2254,  Train Accuracy: 92.26%,  Val Loss: 0.3759,  Val Accuracy: 85.80%
# Epoch 58/200,  Train Loss: 0.2240,  Train Accuracy: 92.06%,  Val Loss: 0.3574,  Val Accuracy: 86.05%
# Epoch 59/200,  Train Loss: 0.2271,  Train Accuracy: 92.30%,  Val Loss: 0.3630,  Val Accuracy: 86.65%
# Epoch 60/200,  Train Loss: 0.2203,  Train Accuracy: 92.38%,  Val Loss: 0.3696,  Val Accuracy: 86.15%
# Epoch 00061: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 61/200,  Train Loss: 0.2167,  Train Accuracy: 92.55%,  Val Loss: 0.3547,  Val Accuracy: 86.45%
# Epoch 62/200,  Train Loss: 0.1991,  Train Accuracy: 93.15%,  Val Loss: 0.3525,  Val Accuracy: 86.95%
# Epoch 63/200,  Train Loss: 0.1922,  Train Accuracy: 93.74%,  Val Loss: 0.3495,  Val Accuracy: 86.50%
# Epoch 64/200,  Train Loss: 0.1925,  Train Accuracy: 93.71%,  Val Loss: 0.3502,  Val Accuracy: 86.60%
# Epoch 65/200,  Train Loss: 0.1968,  Train Accuracy: 93.58%,  Val Loss: 0.3502,  Val Accuracy: 86.50%
# Epoch 66/200,  Train Loss: 0.1925,  Train Accuracy: 93.85%,  Val Loss: 0.3571,  Val Accuracy: 86.65%
# Epoch 67/200,  Train Loss: 0.1896,  Train Accuracy: 94.14%,  Val Loss: 0.3519,  Val Accuracy: 86.90%
# Epoch 68/200,  Train Loss: 0.1916,  Train Accuracy: 93.71%,  Val Loss: 0.3525,  Val Accuracy: 86.60%
# Epoch 00069: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 69/200,  Train Loss: 0.1912,  Train Accuracy: 93.75%,  Val Loss: 0.3520,  Val Accuracy: 86.70%
# Epoch 70/200,  Train Loss: 0.1905,  Train Accuracy: 93.92%,  Val Loss: 0.3546,  Val Accuracy: 86.35%
# Epoch 71/200,  Train Loss: 0.1864,  Train Accuracy: 94.10%,  Val Loss: 0.3524,  Val Accuracy: 86.65%
# Epoch 72/200,  Train Loss: 0.1904,  Train Accuracy: 93.95%,  Val Loss: 0.3557,  Val Accuracy: 86.85%
# Epoch 73/200,  Train Loss: 0.1864,  Train Accuracy: 93.90%,  Val Loss: 0.3516,  Val Accuracy: 86.50%
# Stopping at epoch 73 due to no improvement in validation loss over 10 epochs.
# Results for Fold 5/5:
#  Best Epoch: 63,  Train Loss: 0.1922,  Train Accuracy: 93.74%, Val Loss: 0.3495,  Val Accuracy: 86.50%
#
# Final Results for Learning Rate 0.0001 and Dropout Rate 0.0001:
#  Avg Train Loss: 0.2235,  Avg Train Accuracy: 92.49%,  Avg Val Loss: 0.3425,  Avg Val Accuracy: 87.50%
#
#
# ---------------------------------------------------
# --- Learning Rate: 0.0001, Dropout Rate: 0.0010 ---
# ---------------------------------------------------
#
# Running Fold 1/5..
# Epoch 1/200,  Train Loss: 1.2216,  Train Accuracy: 62.35%,  Val Loss: 1.0410,  Val Accuracy: 73.35%
# Epoch 2/200,  Train Loss: 0.9999,  Train Accuracy: 76.54%,  Val Loss: 0.9413,  Val Accuracy: 78.65%
# Epoch 3/200,  Train Loss: 0.9134,  Train Accuracy: 78.92%,  Val Loss: 0.8690,  Val Accuracy: 78.75%
# Epoch 4/200,  Train Loss: 0.8426,  Train Accuracy: 80.25%,  Val Loss: 0.7989,  Val Accuracy: 81.40%
# Epoch 5/200,  Train Loss: 0.7856,  Train Accuracy: 81.12%,  Val Loss: 0.7400,  Val Accuracy: 81.85%
# Epoch 6/200,  Train Loss: 0.7351,  Train Accuracy: 81.90%,  Val Loss: 0.7007,  Val Accuracy: 81.90%
# Epoch 7/200,  Train Loss: 0.6918,  Train Accuracy: 81.89%,  Val Loss: 0.6585,  Val Accuracy: 83.20%
# Epoch 8/200,  Train Loss: 0.6577,  Train Accuracy: 82.78%,  Val Loss: 0.6288,  Val Accuracy: 83.35%
# Epoch 9/200,  Train Loss: 0.6242,  Train Accuracy: 83.11%,  Val Loss: 0.5973,  Val Accuracy: 83.85%
# Epoch 10/200,  Train Loss: 0.5982,  Train Accuracy: 83.11%,  Val Loss: 0.5682,  Val Accuracy: 84.50%
# Epoch 11/200,  Train Loss: 0.5711,  Train Accuracy: 83.39%,  Val Loss: 0.5509,  Val Accuracy: 84.05%
# Epoch 12/200,  Train Loss: 0.5467,  Train Accuracy: 84.55%,  Val Loss: 0.5303,  Val Accuracy: 84.60%
# Epoch 13/200,  Train Loss: 0.5285,  Train Accuracy: 84.60%,  Val Loss: 0.5122,  Val Accuracy: 84.60%
# Epoch 14/200,  Train Loss: 0.5099,  Train Accuracy: 84.80%,  Val Loss: 0.4961,  Val Accuracy: 84.45%
# Epoch 15/200,  Train Loss: 0.4957,  Train Accuracy: 84.75%,  Val Loss: 0.4983,  Val Accuracy: 83.95%
# Epoch 16/200,  Train Loss: 0.4755,  Train Accuracy: 85.51%,  Val Loss: 0.4793,  Val Accuracy: 84.80%
# Epoch 17/200,  Train Loss: 0.4648,  Train Accuracy: 85.59%,  Val Loss: 0.4639,  Val Accuracy: 85.35%
# Epoch 18/200,  Train Loss: 0.4560,  Train Accuracy: 85.32%,  Val Loss: 0.4530,  Val Accuracy: 85.85%
# Epoch 19/200,  Train Loss: 0.4378,  Train Accuracy: 86.25%,  Val Loss: 0.4396,  Val Accuracy: 86.15%
# Epoch 20/200,  Train Loss: 0.4300,  Train Accuracy: 86.22%,  Val Loss: 0.4398,  Val Accuracy: 85.40%
# Epoch 21/200,  Train Loss: 0.4196,  Train Accuracy: 86.17%,  Val Loss: 0.4300,  Val Accuracy: 85.90%
# Epoch 22/200,  Train Loss: 0.4093,  Train Accuracy: 86.56%,  Val Loss: 0.4311,  Val Accuracy: 85.50%
# Epoch 23/200,  Train Loss: 0.4045,  Train Accuracy: 86.12%,  Val Loss: 0.4165,  Val Accuracy: 85.45%
# Epoch 24/200,  Train Loss: 0.3978,  Train Accuracy: 86.61%,  Val Loss: 0.4105,  Val Accuracy: 85.65%
# Epoch 25/200,  Train Loss: 0.3891,  Train Accuracy: 87.08%,  Val Loss: 0.4082,  Val Accuracy: 86.40%
# Epoch 26/200,  Train Loss: 0.3825,  Train Accuracy: 86.85%,  Val Loss: 0.3963,  Val Accuracy: 86.60%
# Epoch 27/200,  Train Loss: 0.3741,  Train Accuracy: 87.11%,  Val Loss: 0.3990,  Val Accuracy: 86.70%
# Epoch 28/200,  Train Loss: 0.3710,  Train Accuracy: 87.48%,  Val Loss: 0.3902,  Val Accuracy: 85.75%
# Epoch 29/200,  Train Loss: 0.3581,  Train Accuracy: 87.80%,  Val Loss: 0.3857,  Val Accuracy: 86.45%
# Epoch 30/200,  Train Loss: 0.3531,  Train Accuracy: 87.58%,  Val Loss: 0.3830,  Val Accuracy: 86.45%
# Epoch 31/200,  Train Loss: 0.3516,  Train Accuracy: 87.85%,  Val Loss: 0.3799,  Val Accuracy: 86.75%
# Epoch 32/200,  Train Loss: 0.3423,  Train Accuracy: 88.00%,  Val Loss: 0.3782,  Val Accuracy: 85.95%
# Epoch 33/200,  Train Loss: 0.3390,  Train Accuracy: 88.11%,  Val Loss: 0.3784,  Val Accuracy: 86.10%
# Epoch 34/200,  Train Loss: 0.3390,  Train Accuracy: 88.29%,  Val Loss: 0.3739,  Val Accuracy: 86.70%
# Epoch 35/200,  Train Loss: 0.3298,  Train Accuracy: 88.36%,  Val Loss: 0.3733,  Val Accuracy: 85.50%
# Epoch 36/200,  Train Loss: 0.3281,  Train Accuracy: 88.54%,  Val Loss: 0.3634,  Val Accuracy: 86.80%
# Epoch 37/200,  Train Loss: 0.3200,  Train Accuracy: 88.46%,  Val Loss: 0.3678,  Val Accuracy: 86.75%
# Epoch 38/200,  Train Loss: 0.3174,  Train Accuracy: 88.89%,  Val Loss: 0.3612,  Val Accuracy: 86.55%
# Epoch 39/200,  Train Loss: 0.3171,  Train Accuracy: 88.66%,  Val Loss: 0.3536,  Val Accuracy: 87.00%
# Epoch 40/200,  Train Loss: 0.3044,  Train Accuracy: 89.53%,  Val Loss: 0.3576,  Val Accuracy: 86.95%
# Epoch 41/200,  Train Loss: 0.3084,  Train Accuracy: 89.15%,  Val Loss: 0.3595,  Val Accuracy: 87.30%
# Epoch 42/200,  Train Loss: 0.3041,  Train Accuracy: 89.49%,  Val Loss: 0.3544,  Val Accuracy: 87.20%
# Epoch 43/200,  Train Loss: 0.3015,  Train Accuracy: 89.08%,  Val Loss: 0.3502,  Val Accuracy: 87.25%
# Epoch 44/200,  Train Loss: 0.2934,  Train Accuracy: 89.35%,  Val Loss: 0.3447,  Val Accuracy: 87.30%
# Epoch 45/200,  Train Loss: 0.3009,  Train Accuracy: 88.91%,  Val Loss: 0.3534,  Val Accuracy: 87.25%
# Epoch 46/200,  Train Loss: 0.2865,  Train Accuracy: 89.62%,  Val Loss: 0.3523,  Val Accuracy: 86.90%
# Epoch 47/200,  Train Loss: 0.2881,  Train Accuracy: 89.56%,  Val Loss: 0.3463,  Val Accuracy: 86.95%
# Epoch 48/200,  Train Loss: 0.2912,  Train Accuracy: 89.20%,  Val Loss: 0.3579,  Val Accuracy: 86.20%
# Epoch 49/200,  Train Loss: 0.2835,  Train Accuracy: 89.61%,  Val Loss: 0.3457,  Val Accuracy: 87.35%
# Epoch 50/200,  Train Loss: 0.2835,  Train Accuracy: 89.66%,  Val Loss: 0.3410,  Val Accuracy: 87.60%
# Epoch 51/200,  Train Loss: 0.2739,  Train Accuracy: 90.00%,  Val Loss: 0.3450,  Val Accuracy: 86.85%
# Epoch 52/200,  Train Loss: 0.2709,  Train Accuracy: 90.24%,  Val Loss: 0.3466,  Val Accuracy: 87.30%
# Epoch 53/200,  Train Loss: 0.2708,  Train Accuracy: 90.30%,  Val Loss: 0.3463,  Val Accuracy: 87.70%
# Epoch 54/200,  Train Loss: 0.2671,  Train Accuracy: 90.14%,  Val Loss: 0.3385,  Val Accuracy: 87.15%
# Epoch 55/200,  Train Loss: 0.2654,  Train Accuracy: 90.42%,  Val Loss: 0.3490,  Val Accuracy: 86.30%
# Epoch 56/200,  Train Loss: 0.2647,  Train Accuracy: 90.53%,  Val Loss: 0.3409,  Val Accuracy: 87.30%
# Epoch 57/200,  Train Loss: 0.2612,  Train Accuracy: 90.51%,  Val Loss: 0.3432,  Val Accuracy: 87.65%
# Epoch 58/200,  Train Loss: 0.2572,  Train Accuracy: 90.75%,  Val Loss: 0.3456,  Val Accuracy: 87.45%
# Epoch 59/200,  Train Loss: 0.2589,  Train Accuracy: 90.25%,  Val Loss: 0.3376,  Val Accuracy: 87.05%
# Epoch 60/200,  Train Loss: 0.2533,  Train Accuracy: 90.79%,  Val Loss: 0.3447,  Val Accuracy: 86.75%
# Epoch 61/200,  Train Loss: 0.2518,  Train Accuracy: 90.81%,  Val Loss: 0.3326,  Val Accuracy: 87.85%
# Epoch 62/200,  Train Loss: 0.2485,  Train Accuracy: 90.86%,  Val Loss: 0.3386,  Val Accuracy: 87.35%
# Epoch 63/200,  Train Loss: 0.2426,  Train Accuracy: 91.34%,  Val Loss: 0.3424,  Val Accuracy: 87.15%
# Epoch 64/200,  Train Loss: 0.2392,  Train Accuracy: 91.46%,  Val Loss: 0.3359,  Val Accuracy: 87.15%
# Epoch 65/200,  Train Loss: 0.2459,  Train Accuracy: 91.31%,  Val Loss: 0.3485,  Val Accuracy: 86.50%
# Epoch 66/200,  Train Loss: 0.2380,  Train Accuracy: 91.55%,  Val Loss: 0.3401,  Val Accuracy: 87.60%
# Epoch 00067: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 67/200,  Train Loss: 0.2426,  Train Accuracy: 91.35%,  Val Loss: 0.3369,  Val Accuracy: 87.15%
# Epoch 68/200,  Train Loss: 0.2205,  Train Accuracy: 92.25%,  Val Loss: 0.3268,  Val Accuracy: 87.40%
# Epoch 69/200,  Train Loss: 0.2173,  Train Accuracy: 92.45%,  Val Loss: 0.3253,  Val Accuracy: 87.55%
# Epoch 70/200,  Train Loss: 0.2193,  Train Accuracy: 92.14%,  Val Loss: 0.3274,  Val Accuracy: 87.75%
# Epoch 71/200,  Train Loss: 0.2188,  Train Accuracy: 92.55%,  Val Loss: 0.3281,  Val Accuracy: 87.35%
# Epoch 72/200,  Train Loss: 0.2157,  Train Accuracy: 92.60%,  Val Loss: 0.3260,  Val Accuracy: 87.45%
# Epoch 73/200,  Train Loss: 0.2124,  Train Accuracy: 92.33%,  Val Loss: 0.3266,  Val Accuracy: 87.35%
# Epoch 74/200,  Train Loss: 0.2187,  Train Accuracy: 92.27%,  Val Loss: 0.3275,  Val Accuracy: 87.45%
# Epoch 00075: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 75/200,  Train Loss: 0.2134,  Train Accuracy: 92.64%,  Val Loss: 0.3275,  Val Accuracy: 87.55%
# Epoch 76/200,  Train Loss: 0.2168,  Train Accuracy: 92.53%,  Val Loss: 0.3268,  Val Accuracy: 87.65%
# Epoch 77/200,  Train Loss: 0.2168,  Train Accuracy: 92.29%,  Val Loss: 0.3272,  Val Accuracy: 87.65%
# Epoch 78/200,  Train Loss: 0.2157,  Train Accuracy: 92.55%,  Val Loss: 0.3265,  Val Accuracy: 87.55%
# Epoch 79/200,  Train Loss: 0.2115,  Train Accuracy: 92.62%,  Val Loss: 0.3277,  Val Accuracy: 87.60%
# Stopping at epoch 79 due to no improvement in validation loss over 10 epochs.
# Results for Fold 1/5:
#  Best Epoch: 69,  Train Loss: 0.2173,  Train Accuracy: 92.45%, Val Loss: 0.3253,  Val Accuracy: 87.55%
#
# Running Fold 2/5..
# Epoch 1/200,  Train Loss: 1.2322,  Train Accuracy: 59.66%,  Val Loss: 1.0625,  Val Accuracy: 74.00%
# Epoch 2/200,  Train Loss: 1.0047,  Train Accuracy: 76.79%,  Val Loss: 0.9508,  Val Accuracy: 76.35%
# Epoch 3/200,  Train Loss: 0.9134,  Train Accuracy: 78.97%,  Val Loss: 0.8786,  Val Accuracy: 78.90%
# Epoch 4/200,  Train Loss: 0.8435,  Train Accuracy: 80.34%,  Val Loss: 0.8180,  Val Accuracy: 79.80%
# Epoch 5/200,  Train Loss: 0.7859,  Train Accuracy: 81.47%,  Val Loss: 0.7668,  Val Accuracy: 80.50%
# Epoch 6/200,  Train Loss: 0.7350,  Train Accuracy: 82.12%,  Val Loss: 0.7230,  Val Accuracy: 80.70%
# Epoch 7/200,  Train Loss: 0.6921,  Train Accuracy: 82.46%,  Val Loss: 0.6838,  Val Accuracy: 81.45%
# Epoch 8/200,  Train Loss: 0.6564,  Train Accuracy: 83.38%,  Val Loss: 0.6513,  Val Accuracy: 81.75%
# Epoch 9/200,  Train Loss: 0.6235,  Train Accuracy: 83.71%,  Val Loss: 0.6188,  Val Accuracy: 82.40%
# ...
# Epoch 82/200,  Train Loss: 0.5636,  Train Accuracy: 77.83%,  Val Loss: 0.4680,  Val Accuracy: 81.75%
# Epoch 83/200,  Train Loss: 0.5616,  Train Accuracy: 77.71%,  Val Loss: 0.4637,  Val Accuracy: 81.85%
# Epoch 00084: reducing learning rate of group 0 to 3.0000e-03.
# Epoch 84/200,  Train Loss: 0.5571,  Train Accuracy: 77.90%,  Val Loss: 0.4670,  Val Accuracy: 81.50%
# Epoch 85/200,  Train Loss: 0.5425,  Train Accuracy: 78.70%,  Val Loss: 0.4573,  Val Accuracy: 82.00%
# Epoch 86/200,  Train Loss: 0.5396,  Train Accuracy: 78.16%,  Val Loss: 0.4536,  Val Accuracy: 81.65%
# Epoch 87/200,  Train Loss: 0.5457,  Train Accuracy: 78.30%,  Val Loss: 0.4562,  Val Accuracy: 81.85%
# Epoch 88/200,  Train Loss: 0.5406,  Train Accuracy: 78.05%,  Val Loss: 0.4563,  Val Accuracy: 81.45%
# Epoch 89/200,  Train Loss: 0.5484,  Train Accuracy: 77.91%,  Val Loss: 0.4553,  Val Accuracy: 81.50%
# Epoch 90/200,  Train Loss: 0.5587,  Train Accuracy: 78.24%,  Val Loss: 0.4594,  Val Accuracy: 81.40%
# Epoch 91/200,  Train Loss: 0.5397,  Train Accuracy: 78.77%,  Val Loss: 0.4537,  Val Accuracy: 81.65%
# Epoch 00092: reducing learning rate of group 0 to 3.0000e-04.
# Epoch 92/200,  Train Loss: 0.5444,  Train Accuracy: 78.05%,  Val Loss: 0.4583,  Val Accuracy: 81.50%
# Epoch 93/200,  Train Loss: 0.5457,  Train Accuracy: 78.33%,  Val Loss: 0.4532,  Val Accuracy: 81.75%
# Epoch 94/200,  Train Loss: 0.5464,  Train Accuracy: 78.31%,  Val Loss: 0.4523,  Val Accuracy: 81.70%
# Epoch 95/200,  Train Loss: 0.5494,  Train Accuracy: 78.25%,  Val Loss: 0.4564,  Val Accuracy: 81.75%
# Epoch 96/200,  Train Loss: 0.5450,  Train Accuracy: 78.36%,  Val Loss: 0.4529,  Val Accuracy: 81.80%
# Epoch 97/200,  Train Loss: 0.5494,  Train Accuracy: 78.25%,  Val Loss: 0.4537,  Val Accuracy: 81.55%
# Epoch 98/200,  Train Loss: 0.5428,  Train Accuracy: 78.34%,  Val Loss: 0.4527,  Val Accuracy: 82.05%
# Epoch 99/200,  Train Loss: 0.5420,  Train Accuracy: 78.74%,  Val Loss: 0.4534,  Val Accuracy: 81.75%
# Epoch 00100: reducing learning rate of group 0 to 3.0000e-05.
# Epoch 100/200,  Train Loss: 0.5378,  Train Accuracy: 78.21%,  Val Loss: 0.4543,  Val Accuracy: 81.55%
# Epoch 101/200,  Train Loss: 0.5430,  Train Accuracy: 78.90%,  Val Loss: 0.4536,  Val Accuracy: 81.50%
# Epoch 102/200,  Train Loss: 0.5463,  Train Accuracy: 77.88%,  Val Loss: 0.4555,  Val Accuracy: 81.55%
# Epoch 103/200,  Train Loss: 0.5533,  Train Accuracy: 78.72%,  Val Loss: 0.4552,  Val Accuracy: 81.95%
# Epoch 104/200,  Train Loss: 0.5403,  Train Accuracy: 78.17%,  Val Loss: 0.4514,  Val Accuracy: 81.80%
# Epoch 105/200,  Train Loss: 0.5509,  Train Accuracy: 78.09%,  Val Loss: 0.4538,  Val Accuracy: 81.80%
# Epoch 106/200,  Train Loss: 0.5541,  Train Accuracy: 78.19%,  Val Loss: 0.4560,  Val Accuracy: 81.75%
# Epoch 107/200,  Train Loss: 0.5490,  Train Accuracy: 77.85%,  Val Loss: 0.4526,  Val Accuracy: 81.80%
# Epoch 108/200,  Train Loss: 0.5394,  Train Accuracy: 78.06%,  Val Loss: 0.4542,  Val Accuracy: 81.85%
# Epoch 109/200,  Train Loss: 0.5367,  Train Accuracy: 78.16%,  Val Loss: 0.4561,  Val Accuracy: 81.70%
# Epoch 00110: reducing learning rate of group 0 to 3.0000e-06.
# Epoch 110/200,  Train Loss: 0.5405,  Train Accuracy: 78.51%,  Val Loss: 0.4528,  Val Accuracy: 81.85%
# Epoch 111/200,  Train Loss: 0.5343,  Train Accuracy: 78.72%,  Val Loss: 0.4526,  Val Accuracy: 81.80%
# Epoch 112/200,  Train Loss: 0.5444,  Train Accuracy: 78.30%,  Val Loss: 0.4523,  Val Accuracy: 81.95%
# Epoch 113/200,  Train Loss: 0.5357,  Train Accuracy: 78.51%,  Val Loss: 0.4552,  Val Accuracy: 81.90%
# Epoch 114/200,  Train Loss: 0.5509,  Train Accuracy: 78.62%,  Val Loss: 0.4538,  Val Accuracy: 81.95%
# Stopping at epoch 114 due to no improvement in validation loss over 10 epochs.
# Results for Fold 4/5:
#  Best Epoch: 104,  Train Loss: 0.5403,  Train Accuracy: 78.17%, Val Loss: 0.4514,  Val Accuracy: 81.80%
#
# Running Fold 5/5..
# Epoch 1/200,  Train Loss: 1.5787,  Train Accuracy: 47.60%,  Val Loss: 0.7682,  Val Accuracy: 68.85%
# Epoch 2/200,  Train Loss: 0.9036,  Train Accuracy: 63.39%,  Val Loss: 0.6564,  Val Accuracy: 72.35%
# Epoch 3/200,  Train Loss: 0.8535,  Train Accuracy: 64.94%,  Val Loss: 0.7422,  Val Accuracy: 68.60%
# Epoch 4/200,  Train Loss: 0.8217,  Train Accuracy: 66.22%,  Val Loss: 0.6607,  Val Accuracy: 65.60%
# Epoch 5/200,  Train Loss: 0.8201,  Train Accuracy: 66.46%,  Val Loss: 0.6319,  Val Accuracy: 72.50%
# Epoch 6/200,  Train Loss: 0.8083,  Train Accuracy: 66.47%,  Val Loss: 0.5989,  Val Accuracy: 73.45%
# Epoch 7/200,  Train Loss: 0.8413,  Train Accuracy: 65.38%,  Val Loss: 0.6130,  Val Accuracy: 73.40%
# Epoch 8/200,  Train Loss: 0.8236,  Train Accuracy: 66.70%,  Val Loss: 0.6561,  Val Accuracy: 71.50%
# Epoch 9/200,  Train Loss: 0.8477,  Train Accuracy: 65.38%,  Val Loss: 0.6590,  Val Accuracy: 73.00%
# Epoch 10/200,  Train Loss: 0.8298,  Train Accuracy: 65.67%,  Val Loss: 0.6343,  Val Accuracy: 73.10%
# Epoch 11/200,  Train Loss: 0.8323,  Train Accuracy: 66.11%,  Val Loss: 0.6172,  Val Accuracy: 73.00%
# Epoch 00012: reducing learning rate of group 0 to 3.0000e-02.
# Epoch 12/200,  Train Loss: 0.8327,  Train Accuracy: 65.01%,  Val Loss: 0.6402,  Val Accuracy: 73.65%
# Epoch 13/200,  Train Loss: 0.7488,  Train Accuracy: 69.36%,  Val Loss: 0.5746,  Val Accuracy: 74.10%
# Epoch 14/200,  Train Loss: 0.7227,  Train Accuracy: 70.26%,  Val Loss: 0.5806,  Val Accuracy: 74.50%
# Epoch 15/200,  Train Loss: 0.7151,  Train Accuracy: 70.73%,  Val Loss: 0.5622,  Val Accuracy: 74.60%
# Epoch 16/200,  Train Loss: 0.6966,  Train Accuracy: 71.25%,  Val Loss: 0.5637,  Val Accuracy: 74.00%
# Epoch 17/200,  Train Loss: 0.6920,  Train Accuracy: 71.64%,  Val Loss: 0.5623,  Val Accuracy: 74.90%
# Epoch 18/200,  Train Loss: 0.6855,  Train Accuracy: 71.44%,  Val Loss: 0.5646,  Val Accuracy: 75.35%
# Epoch 19/200,  Train Loss: 0.6854,  Train Accuracy: 71.39%,  Val Loss: 0.5633,  Val Accuracy: 74.80%
# Epoch 20/200,  Train Loss: 0.6809,  Train Accuracy: 71.70%,  Val Loss: 0.5560,  Val Accuracy: 75.30%
# Epoch 21/200,  Train Loss: 0.6685,  Train Accuracy: 71.85%,  Val Loss: 0.5582,  Val Accuracy: 75.30%
# Epoch 22/200,  Train Loss: 0.6786,  Train Accuracy: 71.92%,  Val Loss: 0.5571,  Val Accuracy: 74.45%
# Epoch 23/200,  Train Loss: 0.6715,  Train Accuracy: 71.66%,  Val Loss: 0.5596,  Val Accuracy: 74.70%
# Epoch 24/200,  Train Loss: 0.6869,  Train Accuracy: 72.11%,  Val Loss: 0.5580,  Val Accuracy: 74.80%
# Epoch 25/200,  Train Loss: 0.6734,  Train Accuracy: 71.88%,  Val Loss: 0.5472,  Val Accuracy: 75.40%
# Epoch 26/200,  Train Loss: 0.6648,  Train Accuracy: 72.56%,  Val Loss: 0.5446,  Val Accuracy: 74.75%
# Epoch 27/200,  Train Loss: 0.6555,  Train Accuracy: 73.11%,  Val Loss: 0.5433,  Val Accuracy: 75.40%
# Epoch 28/200,  Train Loss: 0.6474,  Train Accuracy: 72.97%,  Val Loss: 0.5468,  Val Accuracy: 74.85%
# Epoch 29/200,  Train Loss: 0.6587,  Train Accuracy: 72.31%,  Val Loss: 0.5427,  Val Accuracy: 75.20%
# Epoch 30/200,  Train Loss: 0.6603,  Train Accuracy: 72.26%,  Val Loss: 0.5473,  Val Accuracy: 75.05%
# Epoch 31/200,  Train Loss: 0.6445,  Train Accuracy: 72.50%,  Val Loss: 0.5267,  Val Accuracy: 76.00%
# Epoch 32/200,  Train Loss: 0.6508,  Train Accuracy: 72.41%,  Val Loss: 0.5288,  Val Accuracy: 75.80%
# Epoch 33/200,  Train Loss: 0.6417,  Train Accuracy: 72.79%,  Val Loss: 0.5317,  Val Accuracy: 76.65%
# Epoch 34/200,  Train Loss: 0.6374,  Train Accuracy: 73.64%,  Val Loss: 0.5295,  Val Accuracy: 76.45%
# Epoch 35/200,  Train Loss: 0.6452,  Train Accuracy: 72.99%,  Val Loss: 0.5229,  Val Accuracy: 76.40%
# Epoch 36/200,  Train Loss: 0.6413,  Train Accuracy: 73.11%,  Val Loss: 0.5303,  Val Accuracy: 78.15%
# Epoch 37/200,  Train Loss: 0.6345,  Train Accuracy: 73.16%,  Val Loss: 0.5160,  Val Accuracy: 78.20%
# Epoch 38/200,  Train Loss: 0.6233,  Train Accuracy: 73.49%,  Val Loss: 0.5195,  Val Accuracy: 76.55%
# Epoch 39/200,  Train Loss: 0.6275,  Train Accuracy: 73.06%,  Val Loss: 0.5153,  Val Accuracy: 77.10%
# Epoch 40/200,  Train Loss: 0.6285,  Train Accuracy: 74.01%,  Val Loss: 0.5137,  Val Accuracy: 76.95%
# Epoch 41/200,  Train Loss: 0.6267,  Train Accuracy: 73.40%,  Val Loss: 0.5099,  Val Accuracy: 76.25%
# Epoch 42/200,  Train Loss: 0.6188,  Train Accuracy: 74.22%,  Val Loss: 0.5122,  Val Accuracy: 77.35%
# Epoch 43/200,  Train Loss: 0.6142,  Train Accuracy: 73.92%,  Val Loss: 0.5084,  Val Accuracy: 78.45%
# Epoch 44/200,  Train Loss: 0.6198,  Train Accuracy: 73.91%,  Val Loss: 0.5072,  Val Accuracy: 77.85%
# Epoch 45/200,  Train Loss: 0.6207,  Train Accuracy: 73.83%,  Val Loss: 0.5002,  Val Accuracy: 79.20%
# Epoch 46/200,  Train Loss: 0.6074,  Train Accuracy: 74.80%,  Val Loss: 0.5088,  Val Accuracy: 79.30%
# Epoch 47/200,  Train Loss: 0.6246,  Train Accuracy: 74.70%,  Val Loss: 0.5003,  Val Accuracy: 79.05%
# Epoch 48/200,  Train Loss: 0.6155,  Train Accuracy: 74.58%,  Val Loss: 0.4998,  Val Accuracy: 78.85%
# Epoch 49/200,  Train Loss: 0.6094,  Train Accuracy: 74.69%,  Val Loss: 0.4933,  Val Accuracy: 77.90%
# Epoch 50/200,  Train Loss: 0.6060,  Train Accuracy: 75.54%,  Val Loss: 0.4904,  Val Accuracy: 78.95%
# Epoch 51/200,  Train Loss: 0.6158,  Train Accuracy: 74.61%,  Val Loss: 0.4915,  Val Accuracy: 78.95%
# Epoch 52/200,  Train Loss: 0.5929,  Train Accuracy: 75.01%,  Val Loss: 0.4885,  Val Accuracy: 79.95%
# Epoch 53/200,  Train Loss: 0.5942,  Train Accuracy: 75.62%,  Val Loss: 0.4885,  Val Accuracy: 79.55%
# Epoch 54/200,  Train Loss: 0.6028,  Train Accuracy: 74.86%,  Val Loss: 0.4818,  Val Accuracy: 80.30%
# Epoch 55/200,  Train Loss: 0.6064,  Train Accuracy: 74.54%,  Val Loss: 0.4939,  Val Accuracy: 80.00%
# Epoch 56/200,  Train Loss: 0.6004,  Train Accuracy: 74.90%,  Val Loss: 0.4804,  Val Accuracy: 81.00%
# Epoch 57/200,  Train Loss: 0.5936,  Train Accuracy: 75.88%,  Val Loss: 0.4854,  Val Accuracy: 81.20%
# Epoch 58/200,  Train Loss: 0.5877,  Train Accuracy: 75.76%,  Val Loss: 0.4738,  Val Accuracy: 81.40%
# Epoch 59/200,  Train Loss: 0.5870,  Train Accuracy: 76.01%,  Val Loss: 0.4680,  Val Accuracy: 81.55%
# Epoch 60/200,  Train Loss: 0.5957,  Train Accuracy: 75.54%,  Val Loss: 0.4732,  Val Accuracy: 81.40%
# Epoch 61/200,  Train Loss: 0.5956,  Train Accuracy: 76.16%,  Val Loss: 0.4781,  Val Accuracy: 81.55%
# Epoch 62/200,  Train Loss: 0.5874,  Train Accuracy: 76.10%,  Val Loss: 0.4719,  Val Accuracy: 81.20%
# Epoch 63/200,  Train Loss: 0.5895,  Train Accuracy: 76.36%,  Val Loss: 0.4645,  Val Accuracy: 82.05%
# Epoch 64/200,  Train Loss: 0.5961,  Train Accuracy: 76.08%,  Val Loss: 0.4654,  Val Accuracy: 80.10%
# Epoch 65/200,  Train Loss: 0.5802,  Train Accuracy: 76.41%,  Val Loss: 0.4595,  Val Accuracy: 82.10%
# Epoch 66/200,  Train Loss: 0.5791,  Train Accuracy: 77.09%,  Val Loss: 0.4537,  Val Accuracy: 81.35%
# Epoch 67/200,  Train Loss: 0.5653,  Train Accuracy: 77.64%,  Val Loss: 0.4479,  Val Accuracy: 82.45%
# Epoch 68/200,  Train Loss: 0.5685,  Train Accuracy: 77.25%,  Val Loss: 0.4561,  Val Accuracy: 82.30%
# Epoch 69/200,  Train Loss: 0.5669,  Train Accuracy: 77.24%,  Val Loss: 0.4439,  Val Accuracy: 82.00%
# Epoch 70/200,  Train Loss: 0.5678,  Train Accuracy: 77.10%,  Val Loss: 0.4528,  Val Accuracy: 82.50%
# Epoch 71/200,  Train Loss: 0.5605,  Train Accuracy: 77.66%,  Val Loss: 0.4489,  Val Accuracy: 82.25%
# Epoch 72/200,  Train Loss: 0.5703,  Train Accuracy: 77.09%,  Val Loss: 0.4560,  Val Accuracy: 82.65%
# Epoch 73/200,  Train Loss: 0.5610,  Train Accuracy: 77.51%,  Val Loss: 0.4441,  Val Accuracy: 81.35%
# Epoch 74/200,  Train Loss: 0.5552,  Train Accuracy: 77.91%,  Val Loss: 0.4519,  Val Accuracy: 82.15%
# Epoch 00075: reducing learning rate of group 0 to 3.0000e-03.
# Epoch 75/200,  Train Loss: 0.5563,  Train Accuracy: 78.35%,  Val Loss: 0.4479,  Val Accuracy: 82.60%
# Epoch 76/200,  Train Loss: 0.5520,  Train Accuracy: 78.26%,  Val Loss: 0.4365,  Val Accuracy: 82.70%
# Epoch 77/200,  Train Loss: 0.5385,  Train Accuracy: 77.91%,  Val Loss: 0.4324,  Val Accuracy: 82.60%
# Epoch 78/200,  Train Loss: 0.5487,  Train Accuracy: 77.81%,  Val Loss: 0.4316,  Val Accuracy: 82.75%
# Epoch 79/200,  Train Loss: 0.5446,  Train Accuracy: 78.05%,  Val Loss: 0.4336,  Val Accuracy: 82.60%
# Epoch 80/200,  Train Loss: 0.5326,  Train Accuracy: 78.77%,  Val Loss: 0.4310,  Val Accuracy: 82.60%
# Epoch 81/200,  Train Loss: 0.5484,  Train Accuracy: 77.55%,  Val Loss: 0.4354,  Val Accuracy: 82.65%
# Epoch 82/200,  Train Loss: 0.5446,  Train Accuracy: 79.19%,  Val Loss: 0.4311,  Val Accuracy: 82.75%
# Epoch 83/200,  Train Loss: 0.5516,  Train Accuracy: 78.25%,  Val Loss: 0.4300,  Val Accuracy: 82.70%
# Epoch 84/200,  Train Loss: 0.5370,  Train Accuracy: 78.29%,  Val Loss: 0.4298,  Val Accuracy: 82.75%
# Epoch 85/200,  Train Loss: 0.5391,  Train Accuracy: 78.67%,  Val Loss: 0.4278,  Val Accuracy: 82.85%
# Epoch 86/200,  Train Loss: 0.5435,  Train Accuracy: 78.17%,  Val Loss: 0.4303,  Val Accuracy: 82.70%
# Epoch 87/200,  Train Loss: 0.5435,  Train Accuracy: 78.33%,  Val Loss: 0.4285,  Val Accuracy: 82.95%
# Epoch 88/200,  Train Loss: 0.5205,  Train Accuracy: 79.03%,  Val Loss: 0.4267,  Val Accuracy: 82.50%
# Epoch 89/200,  Train Loss: 0.5348,  Train Accuracy: 78.86%,  Val Loss: 0.4302,  Val Accuracy: 82.50%
# Epoch 90/200,  Train Loss: 0.5528,  Train Accuracy: 78.33%,  Val Loss: 0.4301,  Val Accuracy: 82.65%
# Epoch 91/200,  Train Loss: 0.5474,  Train Accuracy: 78.16%,  Val Loss: 0.4313,  Val Accuracy: 82.60%
# Epoch 92/200,  Train Loss: 0.5295,  Train Accuracy: 78.84%,  Val Loss: 0.4289,  Val Accuracy: 82.60%
# Epoch 93/200,  Train Loss: 0.5454,  Train Accuracy: 78.06%,  Val Loss: 0.4312,  Val Accuracy: 82.95%
# Epoch 00094: reducing learning rate of group 0 to 3.0000e-04.
# Epoch 94/200,  Train Loss: 0.5253,  Train Accuracy: 79.06%,  Val Loss: 0.4277,  Val Accuracy: 82.45%
# Epoch 95/200,  Train Loss: 0.5252,  Train Accuracy: 78.64%,  Val Loss: 0.4264,  Val Accuracy: 82.90%
# Epoch 96/200,  Train Loss: 0.5546,  Train Accuracy: 78.54%,  Val Loss: 0.4294,  Val Accuracy: 82.70%
# Epoch 97/200,  Train Loss: 0.5338,  Train Accuracy: 78.47%,  Val Loss: 0.4295,  Val Accuracy: 82.75%
# Epoch 98/200,  Train Loss: 0.5372,  Train Accuracy: 78.35%,  Val Loss: 0.4291,  Val Accuracy: 82.65%
# Epoch 99/200,  Train Loss: 0.5377,  Train Accuracy: 78.61%,  Val Loss: 0.4290,  Val Accuracy: 82.65%
# Epoch 100/200,  Train Loss: 0.5351,  Train Accuracy: 78.77%,  Val Loss: 0.4282,  Val Accuracy: 82.80%
# Epoch 00101: reducing learning rate of group 0 to 3.0000e-05.
# Epoch 101/200,  Train Loss: 0.5418,  Train Accuracy: 78.76%,  Val Loss: 0.4275,  Val Accuracy: 82.70%
# Epoch 102/200,  Train Loss: 0.5347,  Train Accuracy: 78.46%,  Val Loss: 0.4312,  Val Accuracy: 82.65%
# Epoch 103/200,  Train Loss: 0.5333,  Train Accuracy: 78.61%,  Val Loss: 0.4296,  Val Accuracy: 82.60%
# Epoch 104/200,  Train Loss: 0.5436,  Train Accuracy: 78.40%,  Val Loss: 0.4292,  Val Accuracy: 82.65%
# Epoch 105/200,  Train Loss: 0.5375,  Train Accuracy: 78.27%,  Val Loss: 0.4301,  Val Accuracy: 82.70%
# Stopping at epoch 105 due to no improvement in validation loss over 10 epochs.
# Results for Fold 5/5:
#  Best Epoch: 95,  Train Loss: 0.5252,  Train Accuracy: 78.64%, Val Loss: 0.4264,  Val Accuracy: 82.90%
#
# Final Results for Learning Rate 0.3 and Dropout Rate 0.5:
#  Avg Train Loss: 0.5410,  Avg Train Accuracy: 78.38%,  Avg Val Loss: 0.4326,  Avg Val Accuracy: 82.15%
#
#          LR     DPR  Train Loss  Train Accuracy  Val Loss  Val Accuracy
# 0   0.0001  0.0001    0.223509         92.4900  0.342490         87.50
# 1   0.0001  0.0010    0.250604         91.2625  0.333339         87.68
# 2   0.0001  0.0025    0.223020         92.1375  0.315359         88.12
# 3   0.0001  0.0100    0.261940         90.3450  0.313470         88.16
# 4   0.0001  0.1000    0.343432         86.7875  0.307462         88.30
# ..     ...     ...         ...             ...       ...           ...
# 67  0.3000  0.1000    0.299617         88.2125  0.310513         88.22
# 68  0.3000  0.2000    0.332991         86.9825  0.306727         88.16
# 69  0.3000  0.3000    0.401491         84.4925  0.329457         86.94
# 70  0.3000  0.4000    0.455051         82.6725  0.358344         85.96
# 71  0.3000  0.5000    0.541036         78.3800  0.432617         82.15
#
# [72 rows x 6 columns]

# %% [markdown]
# # MODEL ANALYSIS AND TESTING

# %% [markdown]
# ### Train new model on best combination of learning and dropout rate.

# %%
# Split training data into training and validation sets
X_train_new, X_val = X_train[:8000, :], X_train[2000:, :]
y_train_new, y_val = y_train[:8000], y_train[2000:]

# Convert to tensors
X_train_tensor = torch.tensor(X_train_new, dtype = torch.float32).view(-1, 1, 28, 28) # Convert to convolutional input
y_train_tensor = torch.tensor(y_train_new, dtype = torch.long)
X_val_tensor = torch.tensor(X_val, dtype = torch.float32).view(-1, 1, 28, 28) # Convert to convolutional input
y_val_tensor = torch.tensor(y_val, dtype = torch.long)

# Create tensor datasets
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

# Define batch size
batch_size = 64

# Create new model on training data based on best combination of learning and dropout rates
best_lr, best_dpr = best_combination
model = CNN(
            n_classes = len(np.unique(y_train)),
            activation_fn = nn.Sigmoid,
            learning_rate = best_lr,
            dropout_rate = best_dpr,
            optimizer = torch.optim.Adam,
            criterion = nn.CrossEntropyLoss(reduction = 'mean'),
            tr_data = train_dataset,
            val_data = val_dataset,
            n_epochs = 200,
            batch_size = batch_size,
            verbose = False
        )

# Fit model
model.fit()

# %% [markdown]
# ### Plot Loss and Accuracy Statistics.

# %%
# Get loss and accuracy statistics
train_losses = model.train_losses
train_accuracies = model.train_accuracies
val_losses = model.val_losses
val_accuracies = model.val_accuracies

# Get best epoch statistic
best_epoch = model.best_epoch

# Plot curves
plt.figure(figsize = (12, 6))
plt.suptitle(f'Training and Validation Loss and Accuracy\nLearning Rate: {best_lr}, Dropout Rate: {best_dpr}')

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(list(train_losses.keys()), list(train_losses.values()), label = 'Training Loss')
plt.plot(list(val_losses.keys()), list(val_losses.values()), label = 'Validation Loss')
plt.axvline(best_epoch, color = 'red', linestyle = '--', label = 'Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(list(train_accuracies.keys()), list(train_accuracies.values()), label = 'Training Accuracy')
plt.plot(list(val_accuracies.keys()), list(val_accuracies.values()), label = 'Validation Accuracy')
plt.axvline(best_epoch, color = 'red', linestyle = '--', label = 'Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show plot
plt.savefig('cnn_curves.png')
plt.show()

# %% [markdown]
# ### Test Model on Testing Data.

# %%
# Prepare testing data
X_test_tensor = torch.tensor(X_test, dtype = torch.float32).view(-1, 1, 28, 28) # Convert to convolutional input
y_test_tensor = torch.tensor(y_test, dtype = torch.long)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# Load best version of the model
model.load_model()

# Test model
test_statistics = model.test(test_data = test_dataset)
test_loss, test_accuracy = test_statistics['Test Loss'], test_statistics['Test Accuracy']
print(f'Test Results:\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# Test Results:
# Test Loss: 0.3109, Test Accuracy: 89.56%
